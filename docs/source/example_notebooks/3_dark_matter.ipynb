# %% [markdown]
# # Example 3: Dark Matter

# %% [markdown]
# In this example we'll consider a more scientifically motivated problem. Astrophysically, dark matter is observed to fall into spherically symmetric arrangements called "haloes". As a function of spherical radius $r$, the density profile of a halo is typically taken to be the Navarro-Frenk-White (NFW) profile:
#
# $$\rho(r) = \dfrac{\rho_0}{\dfrac{r}{r_s}\left(1 + \dfrac{r}{r_s}\right)^2}$$
#
# This is a 2-parameter profile, with a density scaling $\rho_0$ serving as a normalisation, and a scale radius $r_s$. This is essentially double power law: $\rho \propto r^{-1}$ where $r \ll r_s$ and $\rho \propto r^{-3}$ where $r \gg r_s$.
#
# For the Milky Way, reasonable values are $\rho_0 \approx 4 \times 10^{-22}~\mathrm{kg/m^3} \approx 0.006~\mathrm{M}_\odot / \mathrm{pc}^3$ and $r_s \approx 6 \times 10^{20}~\mathrm{m}\approx 20~\mathrm{kpc}$. We don't need to worry so much about $\rho_0$ as it simply sets the overall normalisation.
#
# In our case, we'll place 2 such haloes in a 3D box and sample some dark matter particles.
#
# It's worth noting that the mass of the NFW profile is divergent unless cut off at some radius. The choice of this radius is a slightly thorny issue, but we'll just say that the density cuts to zero at $10 r_s$.

# %% [markdown]
# ## Python preamble

# %% [markdown]
# Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %% [markdown]
# Matplotlib style file

# %%
plt.style.use('figstyle.mplstyle')

# %% [markdown]
# Set up RNG (this is optional, but it makes results reproducible)

# %%
rng = np.random.default_rng(42)

# %% [markdown]
# ## NFW density

# %% [markdown]
# Function to evaluate density as function of position and halo parameters. A thing  to note here is the `q + 1e-3` in the denominator of the density, which didn't appear in the equation above. This is a way to deal with the divergence at $r=0$: this way when $r \ll r_s$, the density approaches a constant $\rho \rightarrow \rho(r=10^{-3}r_s)$.

# %%
def NFW_density_vectorized(X, rho_0, r_s):
    r = np.linalg.norm(X, axis=-1)
    q = r / r_s
    rho = rho_0 / ((q + 1e-1) * (1 + q)**2)
    m = q > 10
    if np.any(m==True): rho[m] = 0
    return rho

def NFW_density(X, rho_0, r_s):
    r = np.linalg.norm(X, axis=-1)
    q = r / r_s
    if q > 10:
        return 0
    rho = rho_0 / ((q + 1e-1) * (1 + q)**2)
    return rho

# %% [markdown]
# ## Creating halo points with `LintSampler`

# %%
from lintsampler import LintSampler

# %% [markdown]
# Let's do two haloes at different locations, both with scale radii of 0.5 (we could call the units kpc, but really the code is agnostic), but with differing values of $\rho_0$. As it just sets a normalisation, we don't actually need to worry about the precise value of $\rho_0$, only the relative values between the two haloes. The total halo mass is proportional to $\rho_0$, so we'll give one halo twice the $\rho_0$ of the other and recheck later that it got twice the particles.

# %% [markdown]
# First, we prepare the pdf, including setting the parameters for each halo:

# %%
def two_halo_pdf_vectorized(X,centres, rho_0s, scale_radii): 
    return np.sum([NFW_density_vectorized(X-centres[h], rho_0s[h], scale_radii[h]) for h in range(0,len(centres))],axis=0)
    


def two_halo_pdf(X,centres, rho_0s, scale_radii): 
    return np.sum([NFW_density(X-centres[h], rho_0s[h], scale_radii[h]) for h in range(0,len(centres))])

centres = [np.array([0.5, -2.5, 3.0]),np.array([-2.5, -2.0, -5.5])]
rho_0s = [1.0,2.0]
scale_radii = [0.5,0.5]

# %% [markdown]
# Next, we set up the grid we want to sample on:

# %%
# grid sizes: outer grid is 128^3, but central 32^3 replaced with 128^3
N_grid = 128

# set up grid boundaries
h = 15
Xedges = np.linspace(-h, h, N_grid + 1)

# %% [markdown]
# And set up the sampling instance:

# %%
#L = LintSampler((Xedges,Xedges,Xedges),pdf=two_halo_pdf,pdf_args=(centres,rho_0s,scale_radii))

# %%
L = LintSampler((Xedges,Xedges,Xedges),pdf=two_halo_pdf_vectorized,vectorizedpdf=True,pdf_args=(centres,rho_0s,scale_radii))

# %% [markdown]
# Lastly, draw the samples.

# %%
X = L.sample(N=1000000)

# %% [markdown]
# To visualise, we'll first make a histogram as in previous examples:

# %%
plt.hist2d(X[:, 0], X[:, 1], bins=np.linspace(-10, 10, 1000), density=True)
plt.gca().set_aspect('equal', adjustable='box')

plt.colorbar();

# %% [markdown]
# This doesn't look particularly impressive. The thing is that power law functions like the NFW profile have a vast dynamic range, so plotting density in linear space will show you the peak and not much else. Let's instead use a log-scale colour map:

# %%
plt.hist2d(X[:, 0], X[:, 1], bins=np.linspace(-10, 10, 1000), density=True, norm=LogNorm())
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar();

# %% [markdown]
# We can see now that the haloes appear to overlap considerably, at least in $x$ and $y$. However, if we choose a different projection, e.g. $x-z$:

# %%
plt.hist2d(X[:, 0], X[:, 2], bins=np.linspace(-10, 10, 1000), density=True, norm=LogNorm())
plt.plot([-10, 10], [-1.5, -1.5], c='k', ls='dashed')
plt.xlim(-10, 10)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar();

# %% [markdown]
# Still some overlap, but overall the haloes seem to separate much more cleanly in $z$. We can use this to test whether an appropriate number of particles has been sampled in each halo. The lower halo in this plot has twice the mass of the upper halo (because its $\rho_0$ parameter was doubled), so it should have twice the particles. If we take a horizontal line at $z=-1.25$ (the dashed line in the plot), then virtually all of the particles above/below the line will belong to the upper/lower halo (with some cross-contamination).

# %%
m = X[:, 2] > -1.25
print(f"Upper halo fraction: {m.sum() / len(m): .3f}")
print(f"Lower halo fraction: {1 - m.sum() / len(m): .3f}")
# Out:
# Upper halo fraction:  0.336
# Lower halo fraction:  0.664

# %% [markdown]
# Looks great!

# %%
from lintsampler import DensityTree

# %%
tree = DensityTree(mins=np.array([-h,-h,-h]), maxs=np.array([h,h,h]), pdf=two_halo_pdf_vectorized, vectorizedpdf=True, min_openings=1,pdf_args=(centres,rho_0s,scale_radii),usecache=False)

# %% [markdown]
# Method one: use the cache.

# %%
tree = DensityTree(mins=np.array([-h,-h,-h]), maxs=np.array([h,h,h]), pdf=two_halo_pdf_vectorized, vectorizedpdf=True, min_openings=4,pdf_args=(centres,rho_0s,scale_radii),usecache=True)    
tree.refine_by_error(leaf_tol=10000., tree_tol=0.005,verbose=True)
# Out:
# Pre-loop: 4096 leaves on tree. Total mass=6.549696766770493
# End of tree iteration 1: 4103 leaves on tree. Total mass=6.7213354080913. Fractional error=0.048161518249817216.
# End of tree iteration 2: 4110 leaves on tree. Total mass=6.8365580750953985. Fractional error=0.04434759035628527.
# End of tree iteration 3: 4117 leaves on tree. Total mass=6.951780742099498. Fractional error=0.04087577142239407.
# End of tree iteration 4: 4124 leaves on tree. Total mass=7.021415703825063. Fractional error=0.03712995456931821.
# End of tree iteration 5: 4131 leaves on tree. Total mass=6.909129422254622. Fractional error=0.0334042579915916.
# End of tree iteration 6: 4138 leaves on tree. Total mass=6.7822310033146715. Fractional error=0.031113110977482813.
# End of tree iteration 7: 4145 leaves on tree. Total mass=6.655332584374722. Fractional error=0.028461846349605132.
# End of tree iteration 8: 4152 leaves on tree. Total mass=6.516909954940919. Fractional error=0.02488371720447024.
# End of tree iteration 9: 4159 leaves on tree. Total mass=6.497320027596274. Fractional error=0.020118781236321208.
# End of tree iteration 10: 4166 leaves on tree. Total mass=6.46161389143428. Fractional error=0.01959665552581597.
# End of tree iteration 11: 4173 leaves on tree. Total mass=6.425907755272286. Fractional error=0.01929050055397898.
# End of tree iteration 12: 4180 leaves on tree. Total mass=6.3802475925115125. Fractional error=0.01895829337314581.
# End of tree iteration 13: 4187 leaves on tree. Total mass=6.482504023606588. Fractional error=0.01880333415043445.
# End of tree iteration 14: 4194 leaves on tree. Total mass=6.470537584087277. Fractional error=0.018167334481704833.
# End of tree iteration 15: 4201 leaves on tree. Total mass=6.454992103226262. Fractional error=0.017817135652138633.
# End of tree iteration 16: 4208 leaves on tree. Total mass=6.439446622365248. Fractional error=0.017486342942438317.
# End of tree iteration 17: 4215 leaves on tree. Total mass=6.421108911633167. Fractional error=0.017137837086011135.
# End of tree iteration 18: 4222 leaves on tree. Total mass=6.461523714347922. Fractional error=0.016806531202093605.
# End of tree iteration 19: 4229 leaves on tree. Total mass=6.452470194042755. Fractional error=0.016304494632715525.
# End of tree iteration 20: 4236 leaves on tree. Total mass=6.727125705256112. Fractional error=0.01580081273051721.
# End of tree iteration 21: 4243 leaves on tree. Total mass=6.8417274800820564. Fractional error=0.01601487566563363.
# End of tree iteration 22: 4250 leaves on tree. Total mass=6.835343101098587. Fractional error=0.015572476482030735.
# End of tree iteration 23: 4257 leaves on tree. Total mass=6.828958722115118. Fractional error=0.015188571074676352.
# End of tree iteration 24: 4264 leaves on tree. Total mass=6.872218836059064. Fractional error=0.014797963814104533.
# End of tree iteration 25: 4271 leaves on tree. Total mass=6.915478950003011. Fractional error=0.01443656892215037.
# End of tree iteration 26: 4278 leaves on tree. Total mass=6.96587957360532. Fractional error=0.014074188439193322.
# End of tree iteration 27: 4285 leaves on tree. Total mass=6.963839948902267. Fractional error=0.013734665833178082.
# End of tree iteration 28: 4292 leaves on tree. Total mass=6.981544993606574. Fractional error=0.013392386289656713.
# End of tree iteration 29: 4299 leaves on tree. Total mass=6.978068289687791. Fractional error=0.01313505519858023.
# End of tree iteration 30: 4306 leaves on tree. Total mass=6.983355449658262. Fractional error=0.01293472174038174.
# End of tree iteration 31: 4313 leaves on tree. Total mass=6.984647167615542. Fractional error=0.012749679839253111.
# End of tree iteration 32: 4320 leaves on tree. Total mass=7.057767792880579. Fractional error=0.012567069643512025.
# End of tree iteration 33: 4327 leaves on tree. Total mass=7.064035441737509. Fractional error=0.01243850002998876.
# End of tree iteration 34: 4334 leaves on tree. Total mass=7.057928540932409. Fractional error=0.012279323056659732.
# End of tree iteration 35: 4341 leaves on tree. Total mass=7.046979729546718. Fractional error=0.012116428061179563.
# End of tree iteration 36: 4348 leaves on tree. Total mass=7.044349589082434. Fractional error=0.012023295719506923.
# End of tree iteration 37: 4355 leaves on tree. Total mass=7.043896929763057. Fractional error=0.011913848639747416.
# End of tree iteration 38: 4362 leaves on tree. Total mass=7.053868000414787. Fractional error=0.011757644677316232.
# End of tree iteration 39: 4369 leaves on tree. Total mass=7.053474044028793. Fractional error=0.011623240828850686.
# End of tree iteration 40: 4376 leaves on tree. Total mass=7.053080087642799. Fractional error=0.011469632186049135.
# End of tree iteration 41: 4383 leaves on tree. Total mass=7.052774133978216. Fractional error=0.011315016420316277.
# End of tree iteration 42: 4390 leaves on tree. Total mass=7.060085438477629. Fractional error=0.01116489008956408.
# End of tree iteration 43: 4397 leaves on tree. Total mass=7.123226381948919. Fractional error=0.011049591377335485.
# End of tree iteration 44: 4404 leaves on tree. Total mass=7.117993409344856. Fractional error=0.010903157250123951.
# End of tree iteration 45: 4411 leaves on tree. Total mass=7.113682023471029. Fractional error=0.010816674621168485.
# End of tree iteration 46: 4418 leaves on tree. Total mass=7.1079695303025145. Fractional error=0.010692838037186743.
# End of tree iteration 47: 4425 leaves on tree. Total mass=7.106615354358539. Fractional error=0.010609075018511972.
# End of tree iteration 48: 4432 leaves on tree. Total mass=7.1052611784145645. Fractional error=0.010479471185576454.
# End of tree iteration 49: 4439 leaves on tree. Total mass=7.103994577363305. Fractional error=0.010348948254336405.
# End of tree iteration 50: 4446 leaves on tree. Total mass=7.102727976312047. Fractional error=0.010227508844753088.
# End of tree iteration 51: 4453 leaves on tree. Total mass=7.095067559203603. Fractional error=0.010105244988280722.
# End of tree iteration 52: 4460 leaves on tree. Total mass=7.094406253119017. Fractional error=0.010041241263938388.
# End of tree iteration 53: 4467 leaves on tree. Total mass=7.092233470733564. Fractional error=0.009958977958177196.
# End of tree iteration 54: 4474 leaves on tree. Total mass=7.122164295936351. Fractional error=0.009878820286196289.
# End of tree iteration 55: 4481 leaves on tree. Total mass=7.1199915135508975. Fractional error=0.009760840710679957.
# End of tree iteration 56: 4488 leaves on tree. Total mass=7.143547000910382. Fractional error=0.009683874399108484.
# End of tree iteration 57: 4495 leaves on tree. Total mass=7.142885694825796. Fractional error=0.009574875455748767.
# End of tree iteration 58: 4502 leaves on tree. Total mass=7.139740100240348. Fractional error=0.00949565073038394.
# End of tree iteration 59: 4509 leaves on tree. Total mass=7.1372184843864925. Fractional error=0.009400459015543155.
# End of tree iteration 60: 4516 leaves on tree. Total mass=7.134696868532638. Fractional error=0.009303810668487612.
# End of tree iteration 61: 4523 leaves on tree. Total mass=7.139196226170898. Fractional error=0.009206472803620658.
# End of tree iteration 62: 4530 leaves on tree. Total mass=7.121078714767487. Fractional error=0.009126413202125027.
# End of tree iteration 63: 4537 leaves on tree. Total mass=7.1160646693207035. Fractional error=0.009106201918208056.
# End of tree iteration 64: 4544 leaves on tree. Total mass=7.138457191051437. Fractional error=0.009045816694001093.
# End of tree iteration 65: 4551 leaves on tree. Total mass=7.132990297357061. Fractional error=0.008967609083138105.
# End of tree iteration 66: 4558 leaves on tree. Total mass=7.1307291326337605. Fractional error=0.008909563041091167.
# End of tree iteration 67: 4565 leaves on tree. Total mass=7.1276652514198435. Fractional error=0.008843416405998032.
# End of tree iteration 68: 4572 leaves on tree. Total mass=7.124601370205925. Fractional error=0.00877966583012871.
# End of tree iteration 69: 4579 leaves on tree. Total mass=7.1223249431910975. Fractional error=0.008714913219811014.
# End of tree iteration 70: 4586 leaves on tree. Total mass=7.12004851617627. Fractional error=0.00862605984912228.
# End of tree iteration 71: 4593 leaves on tree. Total mass=7.117333753443681. Fractional error=0.0085365596939851.
# End of tree iteration 72: 4600 leaves on tree. Total mass=7.108605301864312. Fractional error=0.008456247053195887.
# End of tree iteration 73: 4607 leaves on tree. Total mass=7.1025282149410085. Fractional error=0.008411921003127654.
# End of tree iteration 74: 4614 leaves on tree. Total mass=7.10616177269717. Fractional error=0.008359560862198051.
# End of tree iteration 75: 4621 leaves on tree. Total mass=7.1053093670415945. Fractional error=0.008287624485331727.
# End of tree iteration 76: 4628 leaves on tree. Total mass=7.10445696138602. Fractional error=0.008202551810965339.
# End of tree iteration 77: 4635 leaves on tree. Total mass=7.100286677997014. Fractional error=0.008116929397816563.
# End of tree iteration 78: 4642 leaves on tree. Total mass=7.09483975892356. Fractional error=0.00805874473160882.
# End of tree iteration 79: 4649 leaves on tree. Total mass=7.09655914563238. Fractional error=0.008004847111585384.
# End of tree iteration 80: 4656 leaves on tree. Total mass=7.091911256045991. Fractional error=0.007936413661399614.
# End of tree iteration 81: 4663 leaves on tree. Total mass=7.089099725077371. Fractional error=0.007884629132628919.
# End of tree iteration 82: 4670 leaves on tree. Total mass=7.083052582311582. Fractional error=0.007831428836032437.
# End of tree iteration 83: 4677 leaves on tree. Total mass=7.08145232439537. Fractional error=0.007785529313393331.
# End of tree iteration 84: 4684 leaves on tree. Total mass=7.079852066479157. Fractional error=0.007730837511058696.
# End of tree iteration 85: 4691 leaves on tree. Total mass=7.079101850515932. Fractional error=0.007675833466634141.
# End of tree iteration 86: 4698 leaves on tree. Total mass=7.079041553529717. Fractional error=0.007619301115360314.
# End of tree iteration 87: 4705 leaves on tree. Total mass=7.078981256543503. Fractional error=0.007544969634038927.
# End of tree iteration 88: 4712 leaves on tree. Total mass=7.0782310405802775. Fractional error=0.007470209308739537.
# End of tree iteration 89: 4719 leaves on tree. Total mass=7.078115271038447. Fractional error=0.007412969061402523.
# End of tree iteration 90: 4726 leaves on tree. Total mass=7.078040391056989. Fractional error=0.007338445750080614.
# End of tree iteration 91: 4733 leaves on tree. Total mass=7.078175828040129. Fractional error=0.007266958148937978.
# End of tree iteration 92: 4740 leaves on tree. Total mass=7.083218731917045. Fractional error=0.007199376743406841.
# End of tree iteration 93: 4747 leaves on tree. Total mass=7.0799845566558295. Fractional error=0.007142732731777598.
# End of tree iteration 94: 4754 leaves on tree. Total mass=7.080519521912719. Fractional error=0.00709677457749529.
# End of tree iteration 95: 4761 leaves on tree. Total mass=7.077285346651503. Fractional error=0.00703156170774664.
# End of tree iteration 96: 4768 leaves on tree. Total mass=7.076019263799079. Fractional error=0.006986151928617451.
# End of tree iteration 97: 4775 leaves on tree. Total mass=7.074753180946654. Fractional error=0.006923041213940361.
# End of tree iteration 98: 4782 leaves on tree. Total mass=7.074281031516658. Fractional error=0.006859521148214027.
# End of tree iteration 99: 4789 leaves on tree. Total mass=7.0750436469655416. Fractional error=0.00679488043297498.
# End of tree iteration 100: 4796 leaves on tree. Total mass=7.091565771853508. Fractional error=0.006729896108556321.
# End of tree iteration 101: 4803 leaves on tree. Total mass=7.108087896741474. Fractional error=0.006674804316567629.
# End of tree iteration 102: 4810 leaves on tree. Total mass=7.1090658298376415. Fractional error=0.006619791558118347.
# End of tree iteration 103: 4817 leaves on tree. Total mass=7.109432925116613. Fractional error=0.0065596478251610255.
# End of tree iteration 104: 4824 leaves on tree. Total mass=7.107100569063382. Fractional error=0.006502407832683753.
# End of tree iteration 105: 4831 leaves on tree. Total mass=7.1088886831994. Fractional error=0.0064609965156053875.
# End of tree iteration 106: 4838 leaves on tree. Total mass=7.10655632714617. Fractional error=0.006413114922023908.
# End of tree iteration 107: 4845 leaves on tree. Total mass=7.106658020044897. Fractional error=0.006371260044371964.
# End of tree iteration 108: 4852 leaves on tree. Total mass=7.106974752232307. Fractional error=0.006313966758615837.
# End of tree iteration 109: 4859 leaves on tree. Total mass=7.113013325842892. Fractional error=0.006267325337511801.
# End of tree iteration 110: 4866 leaves on tree. Total mass=7.113186163769605. Fractional error=0.006209309340504748.
# End of tree iteration 111: 4873 leaves on tree. Total mass=7.10540346593506. Fractional error=0.006153144771796595.
# End of tree iteration 112: 4880 leaves on tree. Total mass=7.129532648063295. Fractional error=0.006125445133283849.
# End of tree iteration 113: 4887 leaves on tree. Total mass=7.128532470627128. Fractional error=0.00607548507020744.
# End of tree iteration 114: 4894 leaves on tree. Total mass=7.131636260568193. Fractional error=0.00603518132317863.
# End of tree iteration 115: 4901 leaves on tree. Total mass=7.131837332778851. Fractional error=0.0059920867419900915.
# End of tree iteration 116: 4908 leaves on tree. Total mass=7.129029302724183. Fractional error=0.0059447690313160755.
# End of tree iteration 117: 4915 leaves on tree. Total mass=7.129784579763454. Fractional error=0.005914272595933671.
# End of tree iteration 118: 4922 leaves on tree. Total mass=7.127166028693752. Fractional error=0.005878544385046028.
# End of tree iteration 119: 4929 leaves on tree. Total mass=7.123908978448403. Fractional error=0.005847860706786132.
# End of tree iteration 120: 4936 leaves on tree. Total mass=7.123947451077141. Fractional error=0.005818655202755583.
# End of tree iteration 121: 4943 leaves on tree. Total mass=7.1295056904420875. Fractional error=0.005785096608582652.
# End of tree iteration 122: 4950 leaves on tree. Total mass=7.126975528778438. Fractional error=0.005746928494184889.
# End of tree iteration 123: 4957 leaves on tree. Total mass=7.1258378526904735. Fractional error=0.005718367648078387.
# End of tree iteration 124: 4964 leaves on tree. Total mass=7.124700176602509. Fractional error=0.0056874463914381125.
# End of tree iteration 125: 4971 leaves on tree. Total mass=7.124536962554567. Fractional error=0.005656234134090043.
# End of tree iteration 126: 4978 leaves on tree. Total mass=7.1242044246835565. Fractional error=0.005617843898827655.
# End of tree iteration 127: 4985 leaves on tree. Total mass=7.123871886812546. Fractional error=0.00558131262130346.
# End of tree iteration 128: 4992 leaves on tree. Total mass=7.123535513384931. Fractional error=0.005544625348649732.
# End of tree iteration 129: 4999 leaves on tree. Total mass=7.123199139957315. Fractional error=0.005509305526641183.
# End of tree iteration 130: 5006 leaves on tree. Total mass=7.122792766717238. Fractional error=0.005473838839089174.
# End of tree iteration 131: 5013 leaves on tree. Total mass=7.122386393477161. Fractional error=0.005438735329567337.
# End of tree iteration 132: 5020 leaves on tree. Total mass=7.122132107555567. Fractional error=0.005403481654527768.
# End of tree iteration 133: 5027 leaves on tree. Total mass=7.120476003705847. Fractional error=0.005368750351966632.
# End of tree iteration 134: 5034 leaves on tree. Total mass=7.122757508839887. Fractional error=0.005335559591466996.
# End of tree iteration 135: 5041 leaves on tree. Total mass=7.125039013973928. Fractional error=0.00530546278053855.
# End of tree iteration 136: 5048 leaves on tree. Total mass=7.124817396578214. Fractional error=0.005275178157246153.
# End of tree iteration 137: 5055 leaves on tree. Total mass=7.12456311065662. Fractional error=0.005240655682927252.
# End of tree iteration 138: 5062 leaves on tree. Total mass=7.1241584159172895. Fractional error=0.005206247602676069.
# End of tree iteration 139: 5069 leaves on tree. Total mass=7.123753721177957. Fractional error=0.0051720509992590705.
# End of tree iteration 140: 5076 leaves on tree. Total mass=7.1262819264514246. Fractional error=0.0051376986494169954.
# End of tree iteration 141: 5083 leaves on tree. Total mass=7.124204967816804. Fractional error=0.005101445017054247.
# End of tree iteration 142: 5090 leaves on tree. Total mass=7.121907308850132. Fractional error=0.005069885794626007.
# End of tree iteration 143: 5097 leaves on tree. Total mass=7.121306071332115. Fractional error=0.005044758045333103.
# End of tree iteration 144: 5104 leaves on tree. Total mass=7.12113426848529. Fractional error=0.005012506519070522.
# End of tree iteration 145: 5111 leaves on tree. Total mass=7.120962465638464. Fractional error=0.004980245418383009.

# %% [markdown]
# Method two: don't use the cache.

# %%
tree = DensityTree(mins=np.array([-h,-h,-h]), maxs=np.array([h,h,h]), pdf=two_halo_pdf_vectorized, vectorizedpdf=True, min_openings=4,pdf_args=(centres,rho_0s,scale_radii),usecache=False)    
tree.refine_by_error(leaf_tol=10000., tree_tol=0.005,verbose=True)
# Out:
# Pre-loop: 4096 leaves on tree. Total mass=6.549696766770493
# End of tree iteration 1: 4103 leaves on tree. Total mass=6.7213354080913. Fractional error=0.048161518249817216.
# End of tree iteration 2: 4110 leaves on tree. Total mass=6.8365580750953985. Fractional error=0.04434759035628527.
# End of tree iteration 3: 4117 leaves on tree. Total mass=6.951780742099498. Fractional error=0.04087577142239407.
# End of tree iteration 4: 4124 leaves on tree. Total mass=7.021415703825063. Fractional error=0.03712995456931821.
# End of tree iteration 5: 4131 leaves on tree. Total mass=6.909129422254622. Fractional error=0.0334042579915916.
# End of tree iteration 6: 4138 leaves on tree. Total mass=6.7822310033146715. Fractional error=0.031113110977482813.
# End of tree iteration 7: 4145 leaves on tree. Total mass=6.655332584374722. Fractional error=0.028461846349605132.
# End of tree iteration 8: 4152 leaves on tree. Total mass=6.516909954940919. Fractional error=0.02488371720447024.
# End of tree iteration 9: 4159 leaves on tree. Total mass=6.497320027596274. Fractional error=0.020118781236321208.
# End of tree iteration 10: 4166 leaves on tree. Total mass=6.46161389143428. Fractional error=0.01959665552581597.
# End of tree iteration 11: 4173 leaves on tree. Total mass=6.425907755272286. Fractional error=0.01929050055397898.
# End of tree iteration 12: 4180 leaves on tree. Total mass=6.3802475925115125. Fractional error=0.01895829337314581.
# End of tree iteration 13: 4187 leaves on tree. Total mass=6.482504023606588. Fractional error=0.01880333415043445.
# End of tree iteration 14: 4194 leaves on tree. Total mass=6.470537584087277. Fractional error=0.018167334481704833.
# End of tree iteration 15: 4201 leaves on tree. Total mass=6.454992103226262. Fractional error=0.017817135652138633.
# End of tree iteration 16: 4208 leaves on tree. Total mass=6.439446622365248. Fractional error=0.017486342942438317.
# End of tree iteration 17: 4215 leaves on tree. Total mass=6.421108911633167. Fractional error=0.017137837086011135.
# End of tree iteration 18: 4222 leaves on tree. Total mass=6.461523714347922. Fractional error=0.016806531202093605.
# End of tree iteration 19: 4229 leaves on tree. Total mass=6.452470194042755. Fractional error=0.016304494632715525.
# End of tree iteration 20: 4236 leaves on tree. Total mass=6.727125705256112. Fractional error=0.01580081273051721.
# End of tree iteration 21: 4243 leaves on tree. Total mass=6.8417274800820564. Fractional error=0.01601487566563363.
# End of tree iteration 22: 4250 leaves on tree. Total mass=6.835343101098587. Fractional error=0.015572476482030735.
# End of tree iteration 23: 4257 leaves on tree. Total mass=6.828958722115118. Fractional error=0.015188571074676352.
# End of tree iteration 24: 4264 leaves on tree. Total mass=6.872218836059064. Fractional error=0.014797963814104533.
# End of tree iteration 25: 4271 leaves on tree. Total mass=6.915478950003011. Fractional error=0.01443656892215037.
# End of tree iteration 26: 4278 leaves on tree. Total mass=6.96587957360532. Fractional error=0.014074188439193322.
# End of tree iteration 27: 4285 leaves on tree. Total mass=6.963839948902267. Fractional error=0.013734665833178082.
# End of tree iteration 28: 4292 leaves on tree. Total mass=6.981544993606574. Fractional error=0.013392386289656713.
# End of tree iteration 29: 4299 leaves on tree. Total mass=6.978068289687791. Fractional error=0.01313505519858023.
# End of tree iteration 30: 4306 leaves on tree. Total mass=6.983355449658262. Fractional error=0.01293472174038174.
# End of tree iteration 31: 4313 leaves on tree. Total mass=6.984647167615542. Fractional error=0.012749679839253111.
# End of tree iteration 32: 4320 leaves on tree. Total mass=7.057767792880579. Fractional error=0.012567069643512025.
# End of tree iteration 33: 4327 leaves on tree. Total mass=7.064035441737509. Fractional error=0.01243850002998876.
# End of tree iteration 34: 4334 leaves on tree. Total mass=7.057928540932409. Fractional error=0.012279323056659732.
# End of tree iteration 35: 4341 leaves on tree. Total mass=7.046979729546718. Fractional error=0.012116428061179563.
# End of tree iteration 36: 4348 leaves on tree. Total mass=7.044349589082434. Fractional error=0.012023295719506923.
# End of tree iteration 37: 4355 leaves on tree. Total mass=7.043896929763057. Fractional error=0.011913848639747416.
# End of tree iteration 38: 4362 leaves on tree. Total mass=7.053868000414787. Fractional error=0.011757644677316232.
# End of tree iteration 39: 4369 leaves on tree. Total mass=7.053474044028793. Fractional error=0.011623240828850686.
# End of tree iteration 40: 4376 leaves on tree. Total mass=7.053080087642799. Fractional error=0.011469632186049135.
# End of tree iteration 41: 4383 leaves on tree. Total mass=7.052774133978216. Fractional error=0.011315016420316277.
# End of tree iteration 42: 4390 leaves on tree. Total mass=7.060085438477629. Fractional error=0.01116489008956408.
# End of tree iteration 43: 4397 leaves on tree. Total mass=7.123226381948919. Fractional error=0.011049591377335485.
# End of tree iteration 44: 4404 leaves on tree. Total mass=7.117993409344856. Fractional error=0.010903157250123951.
# End of tree iteration 45: 4411 leaves on tree. Total mass=7.113682023471029. Fractional error=0.010816674621168485.
# End of tree iteration 46: 4418 leaves on tree. Total mass=7.1079695303025145. Fractional error=0.010692838037186743.
# End of tree iteration 47: 4425 leaves on tree. Total mass=7.106615354358539. Fractional error=0.010609075018511972.
# End of tree iteration 48: 4432 leaves on tree. Total mass=7.1052611784145645. Fractional error=0.010479471185576454.
# End of tree iteration 49: 4439 leaves on tree. Total mass=7.103994577363305. Fractional error=0.010348948254336405.
# End of tree iteration 50: 4446 leaves on tree. Total mass=7.102727976312047. Fractional error=0.010227508844753088.
# End of tree iteration 51: 4453 leaves on tree. Total mass=7.095067559203603. Fractional error=0.010105244988280722.
# End of tree iteration 52: 4460 leaves on tree. Total mass=7.094406253119017. Fractional error=0.010041241263938388.
# End of tree iteration 53: 4467 leaves on tree. Total mass=7.092233470733564. Fractional error=0.009958977958177196.
# End of tree iteration 54: 4474 leaves on tree. Total mass=7.122164295936351. Fractional error=0.009878820286196289.
# End of tree iteration 55: 4481 leaves on tree. Total mass=7.1199915135508975. Fractional error=0.009760840710679957.
# End of tree iteration 56: 4488 leaves on tree. Total mass=7.143547000910382. Fractional error=0.009683874399108484.
# End of tree iteration 57: 4495 leaves on tree. Total mass=7.142885694825796. Fractional error=0.009574875455748767.
# End of tree iteration 58: 4502 leaves on tree. Total mass=7.139740100240348. Fractional error=0.00949565073038394.
# End of tree iteration 59: 4509 leaves on tree. Total mass=7.1372184843864925. Fractional error=0.009400459015543155.
# End of tree iteration 60: 4516 leaves on tree. Total mass=7.134696868532638. Fractional error=0.009303810668487612.
# End of tree iteration 61: 4523 leaves on tree. Total mass=7.139196226170898. Fractional error=0.009206472803620658.
# End of tree iteration 62: 4530 leaves on tree. Total mass=7.121078714767487. Fractional error=0.009126413202125027.
# End of tree iteration 63: 4537 leaves on tree. Total mass=7.1160646693207035. Fractional error=0.009106201918208056.
# End of tree iteration 64: 4544 leaves on tree. Total mass=7.138457191051437. Fractional error=0.009045816694001093.
# End of tree iteration 65: 4551 leaves on tree. Total mass=7.132990297357061. Fractional error=0.008967609083138105.
# End of tree iteration 66: 4558 leaves on tree. Total mass=7.1307291326337605. Fractional error=0.008909563041091167.
# End of tree iteration 67: 4565 leaves on tree. Total mass=7.1276652514198435. Fractional error=0.008843416405998032.
# End of tree iteration 68: 4572 leaves on tree. Total mass=7.124601370205925. Fractional error=0.00877966583012871.
# End of tree iteration 69: 4579 leaves on tree. Total mass=7.1223249431910975. Fractional error=0.008714913219811014.
# End of tree iteration 70: 4586 leaves on tree. Total mass=7.12004851617627. Fractional error=0.00862605984912228.
# End of tree iteration 71: 4593 leaves on tree. Total mass=7.117333753443681. Fractional error=0.0085365596939851.
# End of tree iteration 72: 4600 leaves on tree. Total mass=7.108605301864312. Fractional error=0.008456247053195887.
# End of tree iteration 73: 4607 leaves on tree. Total mass=7.1025282149410085. Fractional error=0.008411921003127654.
# End of tree iteration 74: 4614 leaves on tree. Total mass=7.10616177269717. Fractional error=0.008359560862198051.
# End of tree iteration 75: 4621 leaves on tree. Total mass=7.1053093670415945. Fractional error=0.008287624485331727.
# End of tree iteration 76: 4628 leaves on tree. Total mass=7.10445696138602. Fractional error=0.008202551810965339.
# End of tree iteration 77: 4635 leaves on tree. Total mass=7.100286677997014. Fractional error=0.008116929397816563.
# End of tree iteration 78: 4642 leaves on tree. Total mass=7.09483975892356. Fractional error=0.00805874473160882.
# End of tree iteration 79: 4649 leaves on tree. Total mass=7.09655914563238. Fractional error=0.008004847111585384.
# End of tree iteration 80: 4656 leaves on tree. Total mass=7.091911256045991. Fractional error=0.007936413661399614.
# End of tree iteration 81: 4663 leaves on tree. Total mass=7.089099725077371. Fractional error=0.007884629132628919.
# End of tree iteration 82: 4670 leaves on tree. Total mass=7.083052582311582. Fractional error=0.007831428836032437.
# End of tree iteration 83: 4677 leaves on tree. Total mass=7.08145232439537. Fractional error=0.007785529313393331.
# End of tree iteration 84: 4684 leaves on tree. Total mass=7.079852066479157. Fractional error=0.007730837511058696.
# End of tree iteration 85: 4691 leaves on tree. Total mass=7.079101850515932. Fractional error=0.007675833466634141.
# End of tree iteration 86: 4698 leaves on tree. Total mass=7.079041553529717. Fractional error=0.007619301115360314.
# End of tree iteration 87: 4705 leaves on tree. Total mass=7.078981256543503. Fractional error=0.007544969634038927.
# End of tree iteration 88: 4712 leaves on tree. Total mass=7.0782310405802775. Fractional error=0.007470209308739537.
# End of tree iteration 89: 4719 leaves on tree. Total mass=7.078115271038447. Fractional error=0.007412969061402523.
# End of tree iteration 90: 4726 leaves on tree. Total mass=7.078040391056989. Fractional error=0.007338445750080614.
# End of tree iteration 91: 4733 leaves on tree. Total mass=7.078175828040129. Fractional error=0.007266958148937978.
# End of tree iteration 92: 4740 leaves on tree. Total mass=7.083218731917045. Fractional error=0.007199376743406841.
# End of tree iteration 93: 4747 leaves on tree. Total mass=7.0799845566558295. Fractional error=0.007142732731777598.
# End of tree iteration 94: 4754 leaves on tree. Total mass=7.080519521912719. Fractional error=0.00709677457749529.
# End of tree iteration 95: 4761 leaves on tree. Total mass=7.077285346651503. Fractional error=0.00703156170774664.
# End of tree iteration 96: 4768 leaves on tree. Total mass=7.076019263799079. Fractional error=0.006986151928617451.
# End of tree iteration 97: 4775 leaves on tree. Total mass=7.074753180946654. Fractional error=0.006923041213940361.
# End of tree iteration 98: 4782 leaves on tree. Total mass=7.074281031516658. Fractional error=0.006859521148214027.
# End of tree iteration 99: 4789 leaves on tree. Total mass=7.0750436469655416. Fractional error=0.00679488043297498.
# End of tree iteration 100: 4796 leaves on tree. Total mass=7.091565771853508. Fractional error=0.006729896108556321.
# End of tree iteration 101: 4803 leaves on tree. Total mass=7.108087896741474. Fractional error=0.006674804316567629.
# End of tree iteration 102: 4810 leaves on tree. Total mass=7.1090658298376415. Fractional error=0.006619791558118347.
# End of tree iteration 103: 4817 leaves on tree. Total mass=7.109432925116613. Fractional error=0.0065596478251610255.
# End of tree iteration 104: 4824 leaves on tree. Total mass=7.107100569063382. Fractional error=0.006502407832683753.
# End of tree iteration 105: 4831 leaves on tree. Total mass=7.1088886831994. Fractional error=0.0064609965156053875.
# End of tree iteration 106: 4838 leaves on tree. Total mass=7.10655632714617. Fractional error=0.006413114922023908.
# End of tree iteration 107: 4845 leaves on tree. Total mass=7.106658020044897. Fractional error=0.006371260044371964.
# End of tree iteration 108: 4852 leaves on tree. Total mass=7.106974752232307. Fractional error=0.006313966758615837.
# End of tree iteration 109: 4859 leaves on tree. Total mass=7.113013325842892. Fractional error=0.006267325337511801.
# End of tree iteration 110: 4866 leaves on tree. Total mass=7.113186163769605. Fractional error=0.006209309340504748.
# End of tree iteration 111: 4873 leaves on tree. Total mass=7.10540346593506. Fractional error=0.006153144771796595.
# End of tree iteration 112: 4880 leaves on tree. Total mass=7.129532648063295. Fractional error=0.006125445133283849.
# End of tree iteration 113: 4887 leaves on tree. Total mass=7.128532470627128. Fractional error=0.00607548507020744.
# End of tree iteration 114: 4894 leaves on tree. Total mass=7.131636260568193. Fractional error=0.00603518132317863.
# End of tree iteration 115: 4901 leaves on tree. Total mass=7.131837332778851. Fractional error=0.0059920867419900915.
# End of tree iteration 116: 4908 leaves on tree. Total mass=7.129029302724183. Fractional error=0.0059447690313160755.
# End of tree iteration 117: 4915 leaves on tree. Total mass=7.129784579763454. Fractional error=0.005914272595933671.
# End of tree iteration 118: 4922 leaves on tree. Total mass=7.127166028693752. Fractional error=0.005878544385046028.
# End of tree iteration 119: 4929 leaves on tree. Total mass=7.123908978448403. Fractional error=0.005847860706786132.
# End of tree iteration 120: 4936 leaves on tree. Total mass=7.123947451077141. Fractional error=0.005818655202755583.
# End of tree iteration 121: 4943 leaves on tree. Total mass=7.1295056904420875. Fractional error=0.005785096608582652.
# End of tree iteration 122: 4950 leaves on tree. Total mass=7.126975528778438. Fractional error=0.005746928494184889.
# End of tree iteration 123: 4957 leaves on tree. Total mass=7.1258378526904735. Fractional error=0.005718367648078387.
# End of tree iteration 124: 4964 leaves on tree. Total mass=7.124700176602509. Fractional error=0.0056874463914381125.
# End of tree iteration 125: 4971 leaves on tree. Total mass=7.124536962554567. Fractional error=0.005656234134090043.
# End of tree iteration 126: 4978 leaves on tree. Total mass=7.1242044246835565. Fractional error=0.005617843898827655.
# End of tree iteration 127: 4985 leaves on tree. Total mass=7.123871886812546. Fractional error=0.00558131262130346.
# End of tree iteration 128: 4992 leaves on tree. Total mass=7.123535513384931. Fractional error=0.005544625348649732.
# End of tree iteration 129: 4999 leaves on tree. Total mass=7.123199139957315. Fractional error=0.005509305526641183.
# End of tree iteration 130: 5006 leaves on tree. Total mass=7.122792766717238. Fractional error=0.005473838839089174.
# End of tree iteration 131: 5013 leaves on tree. Total mass=7.122386393477161. Fractional error=0.005438735329567337.
# End of tree iteration 132: 5020 leaves on tree. Total mass=7.122132107555567. Fractional error=0.005403481654527768.
# End of tree iteration 133: 5027 leaves on tree. Total mass=7.120476003705847. Fractional error=0.005368750351966632.
# End of tree iteration 134: 5034 leaves on tree. Total mass=7.122757508839887. Fractional error=0.005335559591466996.
# End of tree iteration 135: 5041 leaves on tree. Total mass=7.125039013973928. Fractional error=0.00530546278053855.
# End of tree iteration 136: 5048 leaves on tree. Total mass=7.124817396578214. Fractional error=0.005275178157246153.
# End of tree iteration 137: 5055 leaves on tree. Total mass=7.12456311065662. Fractional error=0.005240655682927252.
# End of tree iteration 138: 5062 leaves on tree. Total mass=7.1241584159172895. Fractional error=0.005206247602676069.
# End of tree iteration 139: 5069 leaves on tree. Total mass=7.123753721177957. Fractional error=0.0051720509992590705.
# End of tree iteration 140: 5076 leaves on tree. Total mass=7.1262819264514246. Fractional error=0.0051376986494169954.
# End of tree iteration 141: 5083 leaves on tree. Total mass=7.124204967816804. Fractional error=0.005101445017054247.
# End of tree iteration 142: 5090 leaves on tree. Total mass=7.121907308850132. Fractional error=0.005069885794626007.
# End of tree iteration 143: 5097 leaves on tree. Total mass=7.121306071332115. Fractional error=0.005044758045333103.
# End of tree iteration 144: 5104 leaves on tree. Total mass=7.12113426848529. Fractional error=0.005012506519070522.
# End of tree iteration 145: 5111 leaves on tree. Total mass=7.120962465638464. Fractional error=0.004980245418383009.

# %% [markdown]
# Method three: batch calls the pdf when opening a cell.

# %%
tree = DensityTree(mins=np.array([-h,-h,-h]), maxs=np.array([h,h,h]), pdf=two_halo_pdf_vectorized, vectorizedpdf=True, min_openings=4,pdf_args=(centres,rho_0s,scale_radii),batch=True)    
tree.refine_by_error(leaf_tol=10000., tree_tol=0.005,verbose=True)
# Out:
# Pre-loop: 4096 leaves on tree. Total mass=6.549696766770493
# End of tree iteration 1: 4103 leaves on tree. Total mass=6.7213354080913. Fractional error=0.048161518249817216.
# End of tree iteration 2: 4110 leaves on tree. Total mass=6.8365580750953985. Fractional error=0.04434759035628527.
# End of tree iteration 3: 4117 leaves on tree. Total mass=6.951780742099498. Fractional error=0.04087577142239407.
# End of tree iteration 4: 4124 leaves on tree. Total mass=7.021415703825063. Fractional error=0.03712995456931821.
# End of tree iteration 5: 4131 leaves on tree. Total mass=6.909129422254622. Fractional error=0.0334042579915916.
# End of tree iteration 6: 4138 leaves on tree. Total mass=6.7822310033146715. Fractional error=0.031113110977482813.
# End of tree iteration 7: 4145 leaves on tree. Total mass=6.655332584374722. Fractional error=0.028461846349605132.
# End of tree iteration 8: 4152 leaves on tree. Total mass=6.516909954940919. Fractional error=0.02488371720447024.
# End of tree iteration 9: 4159 leaves on tree. Total mass=6.497320027596274. Fractional error=0.020118781236321208.
# End of tree iteration 10: 4166 leaves on tree. Total mass=6.46161389143428. Fractional error=0.01959665552581597.
# End of tree iteration 11: 4173 leaves on tree. Total mass=6.425907755272286. Fractional error=0.01929050055397898.
# End of tree iteration 12: 4180 leaves on tree. Total mass=6.3802475925115125. Fractional error=0.01895829337314581.
# End of tree iteration 13: 4187 leaves on tree. Total mass=6.482504023606588. Fractional error=0.01880333415043445.
# End of tree iteration 14: 4194 leaves on tree. Total mass=6.470537584087277. Fractional error=0.018167334481704833.
# End of tree iteration 15: 4201 leaves on tree. Total mass=6.454992103226262. Fractional error=0.017817135652138633.
# End of tree iteration 16: 4208 leaves on tree. Total mass=6.439446622365248. Fractional error=0.017486342942438317.
# End of tree iteration 17: 4215 leaves on tree. Total mass=6.421108911633167. Fractional error=0.017137837086011135.
# End of tree iteration 18: 4222 leaves on tree. Total mass=6.461523714347922. Fractional error=0.016806531202093605.
# End of tree iteration 19: 4229 leaves on tree. Total mass=6.452470194042755. Fractional error=0.016304494632715525.
# End of tree iteration 20: 4236 leaves on tree. Total mass=6.727125705256112. Fractional error=0.01580081273051721.
# End of tree iteration 21: 4243 leaves on tree. Total mass=6.8417274800820564. Fractional error=0.01601487566563363.
# End of tree iteration 22: 4250 leaves on tree. Total mass=6.835343101098587. Fractional error=0.015572476482030735.
# End of tree iteration 23: 4257 leaves on tree. Total mass=6.828958722115118. Fractional error=0.015188571074676352.
# End of tree iteration 24: 4264 leaves on tree. Total mass=6.872218836059064. Fractional error=0.014797963814104533.
# End of tree iteration 25: 4271 leaves on tree. Total mass=6.915478950003011. Fractional error=0.01443656892215037.
# End of tree iteration 26: 4278 leaves on tree. Total mass=6.96587957360532. Fractional error=0.014074188439193322.
# End of tree iteration 27: 4285 leaves on tree. Total mass=6.963839948902267. Fractional error=0.013734665833178082.
# End of tree iteration 28: 4292 leaves on tree. Total mass=6.981544993606574. Fractional error=0.013392386289656713.
# End of tree iteration 29: 4299 leaves on tree. Total mass=6.978068289687791. Fractional error=0.01313505519858023.
# End of tree iteration 30: 4306 leaves on tree. Total mass=6.983355449658262. Fractional error=0.01293472174038174.
# End of tree iteration 31: 4313 leaves on tree. Total mass=6.984647167615542. Fractional error=0.012749679839253111.
# End of tree iteration 32: 4320 leaves on tree. Total mass=7.057767792880579. Fractional error=0.012567069643512025.
# End of tree iteration 33: 4327 leaves on tree. Total mass=7.064035441737509. Fractional error=0.01243850002998876.
# End of tree iteration 34: 4334 leaves on tree. Total mass=7.057928540932409. Fractional error=0.012279323056659732.
# End of tree iteration 35: 4341 leaves on tree. Total mass=7.046979729546718. Fractional error=0.012116428061179563.
# End of tree iteration 36: 4348 leaves on tree. Total mass=7.044349589082434. Fractional error=0.012023295719506923.
# End of tree iteration 37: 4355 leaves on tree. Total mass=7.043896929763057. Fractional error=0.011913848639747416.
# End of tree iteration 38: 4362 leaves on tree. Total mass=7.053868000414787. Fractional error=0.011757644677316232.
# End of tree iteration 39: 4369 leaves on tree. Total mass=7.053474044028793. Fractional error=0.011623240828850686.
# End of tree iteration 40: 4376 leaves on tree. Total mass=7.053080087642799. Fractional error=0.011469632186049135.
# End of tree iteration 41: 4383 leaves on tree. Total mass=7.052774133978216. Fractional error=0.011315016420316277.
# End of tree iteration 42: 4390 leaves on tree. Total mass=7.060085438477629. Fractional error=0.01116489008956408.
# End of tree iteration 43: 4397 leaves on tree. Total mass=7.123226381948919. Fractional error=0.011049591377335485.
# End of tree iteration 44: 4404 leaves on tree. Total mass=7.117993409344856. Fractional error=0.010903157250123951.
# End of tree iteration 45: 4411 leaves on tree. Total mass=7.113682023471029. Fractional error=0.010816674621168485.
# End of tree iteration 46: 4418 leaves on tree. Total mass=7.1079695303025145. Fractional error=0.010692838037186743.
# End of tree iteration 47: 4425 leaves on tree. Total mass=7.106615354358539. Fractional error=0.010609075018511972.
# End of tree iteration 48: 4432 leaves on tree. Total mass=7.1052611784145645. Fractional error=0.010479471185576454.
# End of tree iteration 49: 4439 leaves on tree. Total mass=7.103994577363305. Fractional error=0.010348948254336405.
# End of tree iteration 50: 4446 leaves on tree. Total mass=7.102727976312047. Fractional error=0.010227508844753088.
# End of tree iteration 51: 4453 leaves on tree. Total mass=7.095067559203603. Fractional error=0.010105244988280722.
# End of tree iteration 52: 4460 leaves on tree. Total mass=7.094406253119017. Fractional error=0.010041241263938388.
# End of tree iteration 53: 4467 leaves on tree. Total mass=7.092233470733564. Fractional error=0.009958977958177196.
# End of tree iteration 54: 4474 leaves on tree. Total mass=7.122164295936351. Fractional error=0.009878820286196289.
# End of tree iteration 55: 4481 leaves on tree. Total mass=7.1199915135508975. Fractional error=0.009760840710679957.
# End of tree iteration 56: 4488 leaves on tree. Total mass=7.143547000910382. Fractional error=0.009683874399108484.
# End of tree iteration 57: 4495 leaves on tree. Total mass=7.142885694825796. Fractional error=0.009574875455748767.
# End of tree iteration 58: 4502 leaves on tree. Total mass=7.139740100240348. Fractional error=0.00949565073038394.
# End of tree iteration 59: 4509 leaves on tree. Total mass=7.1372184843864925. Fractional error=0.009400459015543155.
# End of tree iteration 60: 4516 leaves on tree. Total mass=7.134696868532638. Fractional error=0.009303810668487612.
# End of tree iteration 61: 4523 leaves on tree. Total mass=7.139196226170898. Fractional error=0.009206472803620658.
# End of tree iteration 62: 4530 leaves on tree. Total mass=7.121078714767487. Fractional error=0.009126413202125027.
# End of tree iteration 63: 4537 leaves on tree. Total mass=7.1160646693207035. Fractional error=0.009106201918208056.
# End of tree iteration 64: 4544 leaves on tree. Total mass=7.138457191051437. Fractional error=0.009045816694001093.
# End of tree iteration 65: 4551 leaves on tree. Total mass=7.132990297357061. Fractional error=0.008967609083138105.
# End of tree iteration 66: 4558 leaves on tree. Total mass=7.1307291326337605. Fractional error=0.008909563041091167.
# End of tree iteration 67: 4565 leaves on tree. Total mass=7.1276652514198435. Fractional error=0.008843416405998032.
# End of tree iteration 68: 4572 leaves on tree. Total mass=7.124601370205925. Fractional error=0.00877966583012871.
# End of tree iteration 69: 4579 leaves on tree. Total mass=7.1223249431910975. Fractional error=0.008714913219811014.
# End of tree iteration 70: 4586 leaves on tree. Total mass=7.12004851617627. Fractional error=0.00862605984912228.
# End of tree iteration 71: 4593 leaves on tree. Total mass=7.117333753443681. Fractional error=0.0085365596939851.
# End of tree iteration 72: 4600 leaves on tree. Total mass=7.108605301864312. Fractional error=0.008456247053195887.
# End of tree iteration 73: 4607 leaves on tree. Total mass=7.1025282149410085. Fractional error=0.008411921003127654.
# End of tree iteration 74: 4614 leaves on tree. Total mass=7.10616177269717. Fractional error=0.008359560862198051.
# End of tree iteration 75: 4621 leaves on tree. Total mass=7.1053093670415945. Fractional error=0.008287624485331727.
# End of tree iteration 76: 4628 leaves on tree. Total mass=7.10445696138602. Fractional error=0.008202551810965339.
# End of tree iteration 77: 4635 leaves on tree. Total mass=7.100286677997014. Fractional error=0.008116929397816563.
# End of tree iteration 78: 4642 leaves on tree. Total mass=7.09483975892356. Fractional error=0.00805874473160882.
# End of tree iteration 79: 4649 leaves on tree. Total mass=7.09655914563238. Fractional error=0.008004847111585384.
# End of tree iteration 80: 4656 leaves on tree. Total mass=7.091911256045991. Fractional error=0.007936413661399614.
# End of tree iteration 81: 4663 leaves on tree. Total mass=7.089099725077371. Fractional error=0.007884629132628919.
# End of tree iteration 82: 4670 leaves on tree. Total mass=7.083052582311582. Fractional error=0.007831428836032437.
# End of tree iteration 83: 4677 leaves on tree. Total mass=7.08145232439537. Fractional error=0.007785529313393331.
# End of tree iteration 84: 4684 leaves on tree. Total mass=7.079852066479157. Fractional error=0.007730837511058696.
# End of tree iteration 85: 4691 leaves on tree. Total mass=7.079101850515932. Fractional error=0.007675833466634141.
# End of tree iteration 86: 4698 leaves on tree. Total mass=7.079041553529717. Fractional error=0.007619301115360314.
# End of tree iteration 87: 4705 leaves on tree. Total mass=7.078981256543503. Fractional error=0.007544969634038927.
# End of tree iteration 88: 4712 leaves on tree. Total mass=7.0782310405802775. Fractional error=0.007470209308739537.
# End of tree iteration 89: 4719 leaves on tree. Total mass=7.078115271038447. Fractional error=0.007412969061402523.
# End of tree iteration 90: 4726 leaves on tree. Total mass=7.078040391056989. Fractional error=0.007338445750080614.
# End of tree iteration 91: 4733 leaves on tree. Total mass=7.078175828040129. Fractional error=0.007266958148937978.
# End of tree iteration 92: 4740 leaves on tree. Total mass=7.083218731917045. Fractional error=0.007199376743406841.
# End of tree iteration 93: 4747 leaves on tree. Total mass=7.0799845566558295. Fractional error=0.007142732731777598.
# End of tree iteration 94: 4754 leaves on tree. Total mass=7.080519521912719. Fractional error=0.00709677457749529.
# End of tree iteration 95: 4761 leaves on tree. Total mass=7.077285346651503. Fractional error=0.00703156170774664.
# End of tree iteration 96: 4768 leaves on tree. Total mass=7.076019263799079. Fractional error=0.006986151928617451.
# End of tree iteration 97: 4775 leaves on tree. Total mass=7.074753180946654. Fractional error=0.006923041213940361.
# End of tree iteration 98: 4782 leaves on tree. Total mass=7.074281031516658. Fractional error=0.006859521148214027.
# End of tree iteration 99: 4789 leaves on tree. Total mass=7.0750436469655416. Fractional error=0.00679488043297498.
# End of tree iteration 100: 4796 leaves on tree. Total mass=7.091565771853508. Fractional error=0.006729896108556321.
# End of tree iteration 101: 4803 leaves on tree. Total mass=7.108087896741474. Fractional error=0.006674804316567629.
# End of tree iteration 102: 4810 leaves on tree. Total mass=7.1090658298376415. Fractional error=0.006619791558118347.
# End of tree iteration 103: 4817 leaves on tree. Total mass=7.109432925116613. Fractional error=0.0065596478251610255.
# End of tree iteration 104: 4824 leaves on tree. Total mass=7.107100569063382. Fractional error=0.006502407832683753.
# End of tree iteration 105: 4831 leaves on tree. Total mass=7.1088886831994. Fractional error=0.0064609965156053875.
# End of tree iteration 106: 4838 leaves on tree. Total mass=7.10655632714617. Fractional error=0.006413114922023908.
# End of tree iteration 107: 4845 leaves on tree. Total mass=7.106658020044897. Fractional error=0.006371260044371964.
# End of tree iteration 108: 4852 leaves on tree. Total mass=7.106974752232307. Fractional error=0.006313966758615837.
# End of tree iteration 109: 4859 leaves on tree. Total mass=7.113013325842892. Fractional error=0.006267325337511801.
# End of tree iteration 110: 4866 leaves on tree. Total mass=7.113186163769605. Fractional error=0.006209309340504748.
# End of tree iteration 111: 4873 leaves on tree. Total mass=7.10540346593506. Fractional error=0.006153144771796595.
# End of tree iteration 112: 4880 leaves on tree. Total mass=7.129532648063295. Fractional error=0.006125445133283849.
# End of tree iteration 113: 4887 leaves on tree. Total mass=7.128532470627128. Fractional error=0.00607548507020744.
# End of tree iteration 114: 4894 leaves on tree. Total mass=7.131636260568193. Fractional error=0.00603518132317863.
# End of tree iteration 115: 4901 leaves on tree. Total mass=7.131837332778851. Fractional error=0.0059920867419900915.
# End of tree iteration 116: 4908 leaves on tree. Total mass=7.129029302724183. Fractional error=0.0059447690313160755.
# End of tree iteration 117: 4915 leaves on tree. Total mass=7.129784579763454. Fractional error=0.005914272595933671.
# End of tree iteration 118: 4922 leaves on tree. Total mass=7.127166028693752. Fractional error=0.005878544385046028.
# End of tree iteration 119: 4929 leaves on tree. Total mass=7.123908978448403. Fractional error=0.005847860706786132.
# End of tree iteration 120: 4936 leaves on tree. Total mass=7.123947451077141. Fractional error=0.005818655202755583.
# End of tree iteration 121: 4943 leaves on tree. Total mass=7.1295056904420875. Fractional error=0.005785096608582652.
# End of tree iteration 122: 4950 leaves on tree. Total mass=7.126975528778438. Fractional error=0.005746928494184889.
# End of tree iteration 123: 4957 leaves on tree. Total mass=7.1258378526904735. Fractional error=0.005718367648078387.
# End of tree iteration 124: 4964 leaves on tree. Total mass=7.124700176602509. Fractional error=0.0056874463914381125.
# End of tree iteration 125: 4971 leaves on tree. Total mass=7.124536962554567. Fractional error=0.005656234134090043.
# End of tree iteration 126: 4978 leaves on tree. Total mass=7.1242044246835565. Fractional error=0.005617843898827655.
# End of tree iteration 127: 4985 leaves on tree. Total mass=7.123871886812546. Fractional error=0.00558131262130346.
# End of tree iteration 128: 4992 leaves on tree. Total mass=7.123535513384931. Fractional error=0.005544625348649732.
# End of tree iteration 129: 4999 leaves on tree. Total mass=7.123199139957315. Fractional error=0.005509305526641183.
# End of tree iteration 130: 5006 leaves on tree. Total mass=7.122792766717238. Fractional error=0.005473838839089174.
# End of tree iteration 131: 5013 leaves on tree. Total mass=7.122386393477161. Fractional error=0.005438735329567337.
# End of tree iteration 132: 5020 leaves on tree. Total mass=7.122132107555567. Fractional error=0.005403481654527768.
# End of tree iteration 133: 5027 leaves on tree. Total mass=7.120476003705847. Fractional error=0.005368750351966632.
# End of tree iteration 134: 5034 leaves on tree. Total mass=7.122757508839887. Fractional error=0.005335559591466996.
# End of tree iteration 135: 5041 leaves on tree. Total mass=7.125039013973928. Fractional error=0.00530546278053855.
# End of tree iteration 136: 5048 leaves on tree. Total mass=7.124817396578214. Fractional error=0.005275178157246153.
# End of tree iteration 137: 5055 leaves on tree. Total mass=7.12456311065662. Fractional error=0.005240655682927252.
# End of tree iteration 138: 5062 leaves on tree. Total mass=7.1241584159172895. Fractional error=0.005206247602676069.
# End of tree iteration 139: 5069 leaves on tree. Total mass=7.123753721177957. Fractional error=0.0051720509992590705.
# End of tree iteration 140: 5076 leaves on tree. Total mass=7.1262819264514246. Fractional error=0.0051376986494169954.
# End of tree iteration 141: 5083 leaves on tree. Total mass=7.124204967816804. Fractional error=0.005101445017054247.
# End of tree iteration 142: 5090 leaves on tree. Total mass=7.121907308850132. Fractional error=0.005069885794626007.
# End of tree iteration 143: 5097 leaves on tree. Total mass=7.121306071332115. Fractional error=0.005044758045333103.
# End of tree iteration 144: 5104 leaves on tree. Total mass=7.12113426848529. Fractional error=0.005012506519070522.
# End of tree iteration 145: 5111 leaves on tree. Total mass=7.120962465638464. Fractional error=0.004980245418383009.

# %%
from matplotlib.patches import Rectangle
fig = plt.figure()
ax = fig.add_subplot(111)

for leaf in tree.leaves:
    rect = Rectangle((leaf.x[0], leaf.x[2]), leaf.dx[0], leaf.dx[2], lw=1, facecolor='none', ec='k', alpha=0.6)
    ax.add_patch(rect)
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
sampler = LintSampler(domain=tree)
X = sampler.sample(N=1000000)

# %%
plt.hist2d(X[:, 0], X[:, 1], bins=np.linspace(-10, 10, 1000), density=True, norm=LogNorm())
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar();

# %%
h
# Out:
# 15
