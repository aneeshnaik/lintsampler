# %% [markdown]
# # Example 3: Dark Matter

# %% [markdown]
# In this example we'll consider a more scientifically motivated problem. Astrophysically, dark matter is observed to fall into spherically symmetric arrangements called "haloes". As a function of spherical radius $r$, the density profile of a halo is typically taken to be the Navarro-Frenk-White (NFW) profile:
#
# $$\rho(r) = \dfrac{\rho_0}{\dfrac{r}{r_s}\left(1 + \dfrac{r}{r_s}\right)^2}$$
#
# This is a 2-parameter profile, with a density scaling $\rho_0$ serving as a normalisation, and a scale radius $r_s$. This is essentially double power law: $\rho \propto r^{-1}$ where $r \ll r_s$ and $\rho \propto r^{-3}$ where $r \gg r_s$.
#
# For the Milky Way, reasonable values are $\rho_0 \approx 4 \times 10^{-22}~\mathrm{kg/m^3} \approx 0.006~\mathrm{M}_\odot / \mathrm{pc}^3$ and $r_s \approx 6 \times 10^{20}~\mathrm{m}\approx 20~\mathrm{kpc}$. We don't need to worry so much about $\rho_0$ as it simply sets the overall normalisation.
#
# In our case, we'll place 2 such haloes in a 3D box and sample some dark matter particles.
#
# It's worth noting that the mass of the NFW profile is divergent unless cut off at some radius. The choice of this radius is a slightly thorny issue, but we'll just say that the density cuts to zero at $10 r_s$.

# %% [markdown]
# ## Python preamble

# %% [markdown]
# Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %% [markdown]
# Matplotlib style file

# %%
plt.style.use('figstyle.mplstyle')

# %% [markdown]
# Set up RNG (this is optional, but it makes results reproducible)

# %%
rng = np.random.default_rng(42)

# %% [markdown]
# ## NFW density

# %% [markdown]
# Function to evaluate density as function of position and halo parameters. A thing  to note here is the `q + 1e-3` in the denominator of the density, which didn't appear in the equation above. This is a way to deal with the divergence at $r=0$: this way when $r \ll r_s$, the density approaches a constant $\rho \rightarrow \rho(r=10^{-3}r_s)$.

# %%
def NFW_density_vectorized(X, rho_0, r_s):
    r = np.linalg.norm(X, axis=-1)
    q = r / r_s
    rho = rho_0 / ((q + 1e-1) * (1 + q)**2)
    m = q > 10
    if np.any(m==True): rho[m] = 0
    return rho

def NFW_density(X, rho_0, r_s):
    r = np.linalg.norm(X, axis=-1)
    q = r / r_s
    if q > 10:
        return 0
    rho = rho_0 / ((q + 1e-1) * (1 + q)**2)
    return rho

# %% [markdown]
# ## Creating halo points with `LintSampler`

# %%
from lintsampler import LintSampler

# %% [markdown]
# Let's do two haloes at different locations, both with scale radii of 0.5 (we could call the units kpc, but really the code is agnostic), but with differing values of $\rho_0$. As it just sets a normalisation, we don't actually need to worry about the precise value of $\rho_0$, only the relative values between the two haloes. The total halo mass is proportional to $\rho_0$, so we'll give one halo twice the $\rho_0$ of the other and recheck later that it got twice the particles.

# %% [markdown]
# First, we prepare the pdf, including setting the parameters for each halo:

# %%
def two_halo_pdf_vectorized(X,centres, rho_0s, scale_radii): 
    return np.sum([NFW_density_vectorized(X-centres[h], rho_0s[h], scale_radii[h]) for h in range(0,len(centres))],axis=0)
    


def two_halo_pdf(X,centres, rho_0s, scale_radii): 
    return np.sum([NFW_density(X-centres[h], rho_0s[h], scale_radii[h]) for h in range(0,len(centres))])

centres = [np.array([0.5, -2.5, 3.0]),np.array([-2.5, -2.0, -5.5])]
rho_0s = [1.0,2.0]
scale_radii = [0.5,0.5]

# %% [markdown]
# Next, we set up the grid we want to sample on:

# %%
# grid sizes: outer grid is 128^3, but central 32^3 replaced with 128^3
N_grid = 128

# set up grid boundaries
h = 15
Xedges = np.linspace(-h, h, N_grid + 1)

# %% [markdown]
# And set up the sampling instance (using the vectorized pdf, but you can test the speed against the non-vectorized if you wish!):

# %%
#L = LintSampler((Xedges,Xedges,Xedges),pdf=two_halo_pdf,pdf_args=(centres,rho_0s,scale_radii))
L = LintSampler((Xedges,Xedges,Xedges),pdf=two_halo_pdf_vectorized,vectorizedpdf=True,pdf_args=(centres,rho_0s,scale_radii))

# %% [markdown]
# Lastly, draw the samples.

# %%
X = L.sample(N=1000000)

# %% [markdown]
# To visualise, we'll first make a histogram as in previous examples:

# %%
plt.hist2d(X[:, 0], X[:, 1], bins=np.linspace(-10, 10, 1000), density=True)
plt.gca().set_aspect('equal', adjustable='box')

plt.colorbar();

# %% [markdown]
# This doesn't look particularly impressive. The thing is that power law functions like the NFW profile have a vast dynamic range, so plotting density in linear space will show you the peak and not much else. Let's instead use a log-scale colour map:

# %%
plt.hist2d(X[:, 0], X[:, 1], bins=np.linspace(-10, 10, 1000), density=True, norm=LogNorm())
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar();

# %% [markdown]
# We can see now that the haloes appear to overlap considerably, at least in $x$ and $y$. However, if we choose a different projection, e.g. $x-z$:

# %%
plt.hist2d(X[:, 0], X[:, 2], bins=np.linspace(-10, 10, 1000), density=True, norm=LogNorm())
plt.plot([-10, 10], [-1.5, -1.5], c='k', ls='dashed')
plt.xlim(-10, 10)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar();

# %% [markdown]
# Still some overlap, but overall the haloes seem to separate much more cleanly in $z$. We can use this to test whether an appropriate number of particles has been sampled in each halo. The lower halo in this plot has twice the mass of the upper halo (because its $\rho_0$ parameter was doubled), so it should have twice the particles. If we take a horizontal line at $z=-1.25$ (the dashed line in the plot), then virtually all of the particles above/below the line will belong to the upper/lower halo (with some cross-contamination).

# %%
m = X[:, 2] > -1.25
print(f"Upper halo fraction: {m.sum() / len(m): .3f}")
print(f"Lower halo fraction: {1 - m.sum() / len(m): .3f}")
# Out:
# Upper halo fraction:  0.336
# Lower halo fraction:  0.664

# %% [markdown]
# Looks great!

# %% [markdown]
# ## Can we do better?

# %% [markdown]
# We also have `DensityTree` as an option for sampling from the pdf, with a specified error tolerance. `DensityTree` provides an adaptive way to partition the domain, such that a desired accuracy may be achieved.

# %%
from lintsampler import DensityTree

# %% [markdown]
# We'll start with a very coarse grid and let the tree refinement do most of the work.

# %%
tree = DensityTree(mins=np.array([-h,-h,-h]), maxs=np.array([h,h,h]), pdf=two_halo_pdf_vectorized, vectorizedpdf=True, min_openings=4,pdf_args=(centres,rho_0s,scale_radii))

# %% [markdown]
# We'll choose fairly ambitious tolerances, and keep `verbose` on so we can see the tree construction happen in real time. We are also using the control parameter `leaf_mass_contribution_tol`, which prevents cells from too low mass (in this case less than 1% of the mean cell mass) from further refining. These tend to be low density cells, which may have large fractional errors, but small absolute errors.

# %%
tree.refine_by_error(0.0002,leaf_mass_contribution_tol=0.001,verbose=True)
# Out:
# Pre-loop: 4096 leaves on tree. Total mass=6.549696766770493
# End of leaf iteration 1: 6840 leaves on tree. Total mass=7.711413441420396, with mean leaf mass=0.0011273996259386543
# End of leaf iteration 2: 6896 leaves on tree. Total mass=7.711396222940966, with mean leaf mass=0.0011182419116793744
# End of leaf iteration 3: 6896 leaves on tree. Total mass=7.711396222940966, with mean leaf mass=0.0011182419116793744
# End of tree iteration 1: 6903 leaves on tree. Total mass=7.711396222940966. Fractional error=0.0470104717763973.
# End of tree iteration 2: 6910 leaves on tree. Total mass=7.812840429846256. Fractional error=0.043281677445445095.
# End of tree iteration 3: 6917 leaves on tree. Total mass=7.835666283658027. Fractional error=0.03987372908089425.
# End of tree iteration 4: 6924 leaves on tree. Total mass=7.858544044937627. Fractional error=0.036193743238373946.
# End of tree iteration 5: 6931 leaves on tree. Total mass=7.8184156473505455. Fractional error=0.03252127308420134.
# End of tree iteration 6: 6938 leaves on tree. Total mass=7.530866114960987. Fractional error=0.030223513429919326.
# End of tree iteration 7: 6945 leaves on tree. Total mass=7.224599217067536. Fractional error=0.02756245337788735.
# End of tree iteration 8: 6952 leaves on tree. Total mass=6.91840517549689. Fractional error=0.023975690607669405.
# End of tree iteration 9: 6959 leaves on tree. Total mass=6.597856131042141. Fractional error=0.019181724891941837.
# End of tree iteration 10: 6966 leaves on tree. Total mass=6.532046811552023. Fractional error=0.018646239269495168.
# End of tree iteration 11: 6973 leaves on tree. Total mass=6.447114317878656. Fractional error=0.01832111541863233.
# End of tree iteration 12: 6980 leaves on tree. Total mass=6.362181870494821. Fractional error=0.01796870524575847.
# End of tree iteration 13: 6987 leaves on tree. Total mass=6.266589950117423. Fractional error=0.017790035062380714.
# End of tree iteration 14: 6994 leaves on tree. Total mass=6.385861645081398. Fractional error=0.017181163751524713.
# End of tree iteration 15: 7001 leaves on tree. Total mass=6.340587294156407. Fractional error=0.016818206303986453.
# End of tree iteration 16: 7008 leaves on tree. Total mass=6.2907230793543745. Fractional error=0.016472742313179696.
# End of tree iteration 17: 7015 leaves on tree. Total mass=6.240889823165197. Fractional error=0.01610845983695754.
# End of tree iteration 18: 7022 leaves on tree. Total mass=6.187650102138892. Fractional error=0.01575954054213334.
# End of tree iteration 19: 7029 leaves on tree. Total mass=6.220576819055861. Fractional error=0.015260465467536191.
# End of tree iteration 20: 7036 leaves on tree. Total mass=6.232567106087743. Fractional error=0.014752826651264435.
# End of tree iteration 21: 7043 leaves on tree. Total mass=6.606058177051709. Fractional error=0.015064723588589603.
# End of tree iteration 22: 7050 leaves on tree. Total mass=6.7488040232664925. Fractional error=0.014649663108152624.
# End of tree iteration 23: 7057 leaves on tree. Total mass=6.762596484165012. Fractional error=0.014263789601993475.
# End of tree iteration 24: 7064 leaves on tree. Total mass=6.776388878150408. Fractional error=0.01387039251868898.
# End of tree iteration 25: 7071 leaves on tree. Total mass=6.815884437897308. Fractional error=0.013511794798898222.
# End of tree iteration 26: 7078 leaves on tree. Total mass=6.855380054245536. Fractional error=0.013151513895726375.
# End of tree iteration 27: 7085 leaves on tree. Total mass=6.9073161752545245. Fractional error=0.012816672917573785.
# End of tree iteration 28: 7092 leaves on tree. Total mass=6.925052258461162. Fractional error=0.012470609380635279.
# End of tree iteration 29: 7099 leaves on tree. Total mass=6.931914273441663. Fractional error=0.012208437501530245.
# End of tree iteration 30: 7106 leaves on tree. Total mass=6.908370407159658. Fractional error=0.011997263674708427.
# End of tree iteration 31: 7113 leaves on tree. Total mass=6.897937826006428. Fractional error=0.011804443493574361.
# End of tree iteration 32: 7120 leaves on tree. Total mass=6.883135397778496. Fractional error=0.011612702275330507.
# End of tree iteration 33: 7127 leaves on tree. Total mass=6.9739483295095255. Fractional error=0.011501712246090845.
# End of tree iteration 34: 7134 leaves on tree. Total mass=6.968021620418096. Fractional error=0.011335997921820922.
# End of tree iteration 35: 7141 leaves on tree. Total mass=6.938154561487863. Fractional error=0.011235152224703702.
# End of tree iteration 36: 7148 leaves on tree. Total mass=6.921032511902999. Fractional error=0.011119912471684262.
# End of tree iteration 37: 7155 leaves on tree. Total mass=6.933261478635855. Fractional error=0.010962408221706433.
# End of tree iteration 38: 7162 leaves on tree. Total mass=6.9348345397052515. Fractional error=0.010824977002843964.
# End of tree iteration 39: 7169 leaves on tree. Total mass=6.946929565920803. Fractional error=0.010669765994055109.
# End of tree iteration 40: 7176 leaves on tree. Total mass=6.959024514911432. Fractional error=0.010513333991637466.
# End of tree iteration 41: 7183 leaves on tree. Total mass=6.970995540129242. Fractional error=0.010361302193336943.
# End of tree iteration 42: 7190 leaves on tree. Total mass=6.9695951161929415. Fractional error=0.010242274285726037.
# End of tree iteration 43: 7197 leaves on tree. Total mass=7.0494070159146744. Fractional error=0.010107276101995294.
# End of tree iteration 44: 7204 leaves on tree. Total mass=7.029968791206336. Fractional error=0.010014200958626731.
# End of tree iteration 45: 7211 leaves on tree. Total mass=7.035235401220975. Fractional error=0.009887357892036173.
# End of tree iteration 46: 7218 leaves on tree. Total mass=7.015348763115727. Fractional error=0.009796703909799373.
# End of tree iteration 47: 7225 leaves on tree. Total mass=7.024764565197874. Fractional error=0.00966443709278123.
# End of tree iteration 48: 7232 leaves on tree. Total mass=7.034180300366896. Fractional error=0.009531040911824017.
# End of tree iteration 49: 7239 leaves on tree. Total mass=7.043250775199338. Fractional error=0.009406826211020621.
# End of tree iteration 50: 7246 leaves on tree. Total mass=7.0523211162055315. Fractional error=0.009281587682159607.
# End of tree iteration 51: 7253 leaves on tree. Total mass=7.030788187613797. Fractional error=0.009210415903188175.
# End of tree iteration 52: 7260 leaves on tree. Total mass=7.01940963017703. Fractional error=0.009122231346791783.
# End of tree iteration 53: 7267 leaves on tree. Total mass=7.005851050496214. Fractional error=0.0090356295577776.
# End of tree iteration 54: 7274 leaves on tree. Total mass=7.0390354861264255. Fractional error=0.008919510753277052.
# End of tree iteration 55: 7281 leaves on tree. Total mass=7.025763928291432. Fractional error=0.008836076102979025.
# End of tree iteration 56: 7288 leaves on tree. Total mass=7.049963116509819. Fractional error=0.008727153396196561.
# End of tree iteration 57: 7295 leaves on tree. Total mass=7.039031081233531. Fractional error=0.008641615393070404.
# End of tree iteration 58: 7302 leaves on tree. Total mass=7.043912761608524. Fractional error=0.008542666390306963.
# End of tree iteration 59: 7309 leaves on tree. Total mass=7.049692283228505. Fractional error=0.008442242067090194.
# End of tree iteration 60: 7316 leaves on tree. Total mass=7.055471671022237. Fractional error=0.008340940719845601.
# End of tree iteration 61: 7323 leaves on tree. Total mass=7.0527616014397. Fractional error=0.008255805456569997.
# End of tree iteration 62: 7330 leaves on tree. Total mass=7.017234367676335. Fractional error=0.008226272909802965.
# End of tree iteration 63: 7337 leaves on tree. Total mass=7.00088277393059. Fractional error=0.008158537692560629.
# End of tree iteration 64: 7344 leaves on tree. Total mass=7.024369627230375. Fractional error=0.008081161717028716.
# End of tree iteration 65: 7351 leaves on tree. Total mass=7.007518027712905. Fractional error=0.008015587574217465.
# End of tree iteration 66: 7358 leaves on tree. Total mass=6.995349928394329. Fractional error=0.007942373496222187.
# End of tree iteration 67: 7365 leaves on tree. Total mass=6.982106375066703. Fractional error=0.007871297387325376.
# End of tree iteration 68: 7372 leaves on tree. Total mass=6.968862821753575. Fractional error=0.00779899613179211.
# End of tree iteration 69: 7379 leaves on tree. Total mass=6.974194144680415. Fractional error=0.0077053870946526505.
# End of tree iteration 70: 7386 leaves on tree. Total mass=6.979525400694131. Fractional error=0.007610914862997196.
# End of tree iteration 71: 7393 leaves on tree. Total mass=6.983790438132796. Fractional error=0.007525857350270483.
# End of tree iteration 72: 7400 leaves on tree. Total mass=6.962893304961781. Fractional error=0.007472930769249393.
# End of tree iteration 73: 7407 leaves on tree. Total mass=6.945846397251546. Fractional error=0.007412192128517081.
# End of tree iteration 74: 7414 leaves on tree. Total mass=6.942928030651599. Fractional error=0.007333871162966614.
# End of tree iteration 75: 7421 leaves on tree. Total mass=6.949802129049978. Fractional error=0.007243768706146772.
# End of tree iteration 76: 7428 leaves on tree. Total mass=6.956676170847031. Fractional error=0.007152887983135556.
# End of tree iteration 77: 7435 leaves on tree. Total mass=6.942531060507788. Fractional error=0.007085972419548106.
# End of tree iteration 78: 7442 leaves on tree. Total mass=6.92663724037661. Fractional error=0.007023057516842334.
# End of tree iteration 79: 7449 leaves on tree. Total mass=6.921196995235167. Fractional error=0.0069469931797905326.
# End of tree iteration 80: 7456 leaves on tree. Total mass=6.906778649903282. Fractional error=0.00688642997568289.
# End of tree iteration 81: 7463 leaves on tree. Total mass=6.895253713678086. Fractional error=0.006824961107214576.
# End of tree iteration 82: 7470 leaves on tree. Total mass=6.87907081533953. Fractional error=0.006770003159371107.
# End of tree iteration 83: 7477 leaves on tree. Total mass=6.869429866259129. Fractional error=0.0067071060584236375.
# End of tree iteration 84: 7484 leaves on tree. Total mass=6.859811485116879. Fractional error=0.006643702100342615.
# End of tree iteration 85: 7491 leaves on tree. Total mass=6.851459184571114. Fractional error=0.006578810600864501.
# End of tree iteration 86: 7498 leaves on tree. Total mass=6.8585081704224775. Fractional error=0.006498650933924818.
# End of tree iteration 87: 7505 leaves on tree. Total mass=6.8655570430711865. Fractional error=0.00641782083486988.
# End of tree iteration 88: 7512 leaves on tree. Total mass=6.857272698035921. Fractional error=0.0063516179028944575.
# End of tree iteration 89: 7519 leaves on tree. Total mass=6.857941610909757. Fractional error=0.006290062645362998.
# End of tree iteration 90: 7526 leaves on tree. Total mass=6.846652074791542. Fractional error=0.006237147765505622.
# End of tree iteration 91: 7533 leaves on tree. Total mass=6.835457962934285. Fractional error=0.006185303983508989.
# End of tree iteration 92: 7540 leaves on tree. Total mass=6.840040056804246. Fractional error=0.006117688106315878.
# End of tree iteration 93: 7547 leaves on tree. Total mass=6.844622150662232. Fractional error=0.006049497724074798.
# End of tree iteration 94: 7554 leaves on tree. Total mass=6.862366868373294. Fractional error=0.0059936461214154515.
# End of tree iteration 95: 7561 leaves on tree. Total mass=6.880111586097594. Fractional error=0.0059378117451386655.
# End of tree iteration 96: 7568 leaves on tree. Total mass=6.870807498363155. Fractional error=0.0058923198909817814.
# End of tree iteration 97: 7575 leaves on tree. Total mass=6.867497236170333. Fractional error=0.0058408204351774965.
# End of tree iteration 98: 7582 leaves on tree. Total mass=6.858224859716712. Fractional error=0.005794716737576769.
# End of tree iteration 99: 7589 leaves on tree. Total mass=6.852826428373556. Fractional error=0.005744511494002469.
# End of tree iteration 100: 7596 leaves on tree. Total mass=6.858862549888375. Fractional error=0.005684687619649973.
# End of tree iteration 101: 7603 leaves on tree. Total mass=6.873283599300599. Fractional error=0.005624952818027928.
# End of tree iteration 102: 7610 leaves on tree. Total mass=6.85637422512963. Fractional error=0.005592983976799357.
# End of tree iteration 103: 7617 leaves on tree. Total mass=6.8858280048433596. Fractional error=0.0055441609464947595.
# End of tree iteration 104: 7624 leaves on tree. Total mass=6.878892916042206. Fractional error=0.005500172301491968.
# End of tree iteration 105: 7631 leaves on tree. Total mass=6.878036827456815. Fractional error=0.00545405441056307.
# End of tree iteration 106: 7638 leaves on tree. Total mass=6.868989493608622. Fractional error=0.005420437060234429.
# End of tree iteration 107: 7645 leaves on tree. Total mass=6.865148331636137. Fractional error=0.005381936119121962.
# End of tree iteration 108: 7652 leaves on tree. Total mass=6.856431846269615. Fractional error=0.005348077419495972.
# End of tree iteration 109: 7659 leaves on tree. Total mass=6.84683036574336. Fractional error=0.005315623043933651.
# End of tree iteration 110: 7666 leaves on tree. Total mass=6.8420978934160335. Fractional error=0.005279174621127911.
# End of tree iteration 111: 7673 leaves on tree. Total mass=6.84543813195511. Fractional error=0.005238918138702686.
# End of tree iteration 112: 7680 leaves on tree. Total mass=6.837089452736801. Fractional error=0.005207203739820036.
# End of tree iteration 113: 7687 leaves on tree. Total mass=6.830781325193129. Fractional error=0.00517321781662842.
# End of tree iteration 114: 7694 leaves on tree. Total mass=6.824473197663957. Fractional error=0.005138875660134953.
# End of tree iteration 115: 7701 leaves on tree. Total mass=6.828721451892626. Fractional error=0.005098351089362981.
# End of tree iteration 116: 7708 leaves on tree. Total mass=6.832620102972077. Fractional error=0.005059726972833241.
# End of tree iteration 117: 7715 leaves on tree. Total mass=6.836518676826606. Fractional error=0.0050208945592856965.
# End of tree iteration 118: 7722 leaves on tree. Total mass=6.840316157682909. Fractional error=0.004983476586282806.
# End of tree iteration 119: 7729 leaves on tree. Total mass=6.8441134840893705. Fractional error=0.004945860715594414.
# End of tree iteration 120: 7736 leaves on tree. Total mass=6.847780595442978. Fractional error=0.004908575915746102.
# End of tree iteration 121: 7743 leaves on tree. Total mass=6.851447552346743. Fractional error=0.004871087815863807.
# End of tree iteration 122: 7750 leaves on tree. Total mass=6.855279343739073. Fractional error=0.004834147212109511.
# End of tree iteration 123: 7757 leaves on tree. Total mass=6.854387651891182. Fractional error=0.0048016488195062705.
# End of tree iteration 124: 7764 leaves on tree. Total mass=6.853495960056529. Fractional error=0.004768911797470443.
# End of tree iteration 125: 7771 leaves on tree. Total mass=6.85732928388822. Fractional error=0.004732252714349552.
# End of tree iteration 126: 7778 leaves on tree. Total mass=6.86109352635596. Fractional error=0.004695666054829247.
# End of tree iteration 127: 7785 leaves on tree. Total mass=6.864625798270971. Fractional error=0.004659232228376881.
# End of tree iteration 128: 7792 leaves on tree. Total mass=6.868157992961061. Fractional error=0.004622587224056703.
# End of tree iteration 129: 7799 leaves on tree. Total mass=6.875900736363699. Fractional error=0.0045844613418090175.
# End of tree iteration 130: 7806 leaves on tree. Total mass=6.8769336980298. Fractional error=0.004550387146910733.
# End of tree iteration 131: 7813 leaves on tree. Total mass=6.8694979135907115. Fractional error=0.004521987823233563.
# End of tree iteration 132: 7820 leaves on tree. Total mass=6.872584717994098. Fractional error=0.004487385834304881.
# End of tree iteration 133: 7827 leaves on tree. Total mass=6.876265521326122. Fractional error=0.0044528208381912696.
# End of tree iteration 134: 7834 leaves on tree. Total mass=6.879946324647431. Fractional error=0.004418058941467195.
# End of tree iteration 135: 7841 leaves on tree. Total mass=6.880354644006655. Fractional error=0.004385935692904464.
# End of tree iteration 136: 7848 leaves on tree. Total mass=6.8807629633658784. Fractional error=0.004353583120346054.
# End of tree iteration 137: 7855 leaves on tree. Total mass=6.874802237842259. Fractional error=0.004325165122461352.
# End of tree iteration 138: 7862 leaves on tree. Total mass=6.866535008999197. Fractional error=0.004299580042575728.
# End of tree iteration 139: 7869 leaves on tree. Total mass=6.8603677686356495. Fractional error=0.004272888735150429.
# End of tree iteration 140: 7876 leaves on tree. Total mass=6.863403525366959. Fractional error=0.0042411733443449475.
# End of tree iteration 141: 7883 leaves on tree. Total mass=6.866439282086292. Fractional error=0.004209274856923867.
# End of tree iteration 142: 7890 leaves on tree. Total mass=6.86997676588711. Fractional error=0.004177696687949839.
# End of tree iteration 143: 7897 leaves on tree. Total mass=6.872298226088978. Fractional error=0.0041479885430693916.
# End of tree iteration 144: 7904 leaves on tree. Total mass=6.874619485551472. Fractional error=0.004118109708082947.
# End of tree iteration 145: 7911 leaves on tree. Total mass=6.870459527626172. Fractional error=0.004092468625894509.
# End of tree iteration 146: 7918 leaves on tree. Total mass=6.860290421046172. Fractional error=0.004072600421967437.
# End of tree iteration 147: 7925 leaves on tree. Total mass=6.8638203343442665. Fractional error=0.00404248040819543.
# End of tree iteration 148: 7932 leaves on tree. Total mass=6.855766513236073. Fractional error=0.0040201902104243315.
# End of tree iteration 149: 7939 leaves on tree. Total mass=6.847712738417412. Fractional error=0.003997665047215257.
# End of tree iteration 150: 7946 leaves on tree. Total mass=6.843931968418754. Fractional error=0.003971638637169951.
# End of tree iteration 151: 7953 leaves on tree. Total mass=6.840224054742903. Fractional error=0.003946592417830839.
# End of tree iteration 152: 7960 leaves on tree. Total mass=6.842517508246018. Fractional error=0.003917838280546518.
# End of tree iteration 153: 7967 leaves on tree. Total mass=6.839250122227057. Fractional error=0.003892948529917164.
# End of tree iteration 154: 7974 leaves on tree. Total mass=6.841208875484011. Fractional error=0.0038647580861266633.
# End of tree iteration 155: 7981 leaves on tree. Total mass=6.843945737746964. Fractional error=0.00383655484007396.
# End of tree iteration 156: 7988 leaves on tree. Total mass=6.846682599985968. Fractional error=0.003808187688587176.
# End of tree iteration 157: 7995 leaves on tree. Total mass=6.841750867525997. Fractional error=0.003784625372593283.
# End of tree iteration 158: 8002 leaves on tree. Total mass=6.838678177385482. Fractional error=0.003760187125849849.
# End of tree iteration 159: 8009 leaves on tree. Total mass=6.835605487244967. Fractional error=0.0037355438480861252.
# End of tree iteration 160: 8016 leaves on tree. Total mass=6.837093718701835. Fractional error=0.0037096186759462847.
# End of tree iteration 161: 8023 leaves on tree. Total mass=6.84172967587363. Fractional error=0.0036822421601500083.
# End of tree iteration 162: 8030 leaves on tree. Total mass=6.835682993635958. Fractional error=0.0036632602161076502.
# End of tree iteration 163: 8037 leaves on tree. Total mass=6.829636311427283. Fractional error=0.003644108702363673.
# End of tree iteration 164: 8044 leaves on tree. Total mass=6.831557855905903. Fractional error=0.003620147597627794.
# End of tree iteration 165: 8051 leaves on tree. Total mass=6.836520318050301. Fractional error=0.003596799535137787.
# End of tree iteration 166: 8058 leaves on tree. Total mass=6.836913287553106. Fractional error=0.003575188056131935.
# End of tree iteration 167: 8065 leaves on tree. Total mass=6.838661952976471. Fractional error=0.003552869180199546.
# End of tree iteration 168: 8072 leaves on tree. Total mass=6.8404105824221055. Fractional error=0.0035304326079066174.
# End of tree iteration 169: 8079 leaves on tree. Total mass=6.840974913534595. Fractional error=0.0035094802343405103.
# End of tree iteration 170: 8086 leaves on tree. Total mass=6.84153913144443. Fractional error=0.003488410858711662.
# End of tree iteration 171: 8093 leaves on tree. Total mass=6.842428517027901. Fractional error=0.003467196006271564.
# End of tree iteration 172: 8100 leaves on tree. Total mass=6.842421089168758. Fractional error=0.0034467228085376584.
# End of tree iteration 173: 8107 leaves on tree. Total mass=6.839456226693477. Fractional error=0.0034278075212484634.
# End of tree iteration 174: 8114 leaves on tree. Total mass=6.834855848513445. Fractional error=0.0034111970440996752.
# End of tree iteration 175: 8121 leaves on tree. Total mass=6.834971851797327. Fractional error=0.003392060826739589.
# End of tree iteration 176: 8128 leaves on tree. Total mass=6.835604518075364. Fractional error=0.003372793415274284.
# End of tree iteration 177: 8135 leaves on tree. Total mass=6.838785374890102. Fractional error=0.0033534965083118033.
# End of tree iteration 178: 8142 leaves on tree. Total mass=6.840483464175591. Fractional error=0.003335743917814602.
# End of tree iteration 179: 8149 leaves on tree. Total mass=6.83873091370725. Fractional error=0.0033189123822291245.
# End of tree iteration 180: 8156 leaves on tree. Total mass=6.833478909384741. Fractional error=0.0033042814737849124.
# End of tree iteration 181: 8163 leaves on tree. Total mass=6.8293449359823555. Fractional error=0.0032891400150081643.
# End of tree iteration 182: 8170 leaves on tree. Total mass=6.831379202171663. Fractional error=0.0032706950368824165.
# End of tree iteration 183: 8177 leaves on tree. Total mass=6.833413468347733. Fractional error=0.003252167300709513.
# End of tree iteration 184: 8184 leaves on tree. Total mass=6.83379010507678. Fractional error=0.0032348471107718343.
# End of tree iteration 185: 8191 leaves on tree. Total mass=6.835598582840818. Fractional error=0.003216644789516635.
# End of tree iteration 186: 8198 leaves on tree. Total mass=6.837594359922019. Fractional error=0.003198539494916687.
# End of tree iteration 187: 8205 leaves on tree. Total mass=6.835392129230961. Fractional error=0.0031821891654635896.
# End of tree iteration 188: 8212 leaves on tree. Total mass=6.836936318347634. Fractional error=0.0031640540768524475.
# End of tree iteration 189: 8219 leaves on tree. Total mass=6.823087467445072. Fractional error=0.0031659964465868703.
# End of tree iteration 190: 8226 leaves on tree. Total mass=6.821510957163453. Fractional error=0.003149768362217512.
# End of tree iteration 191: 8233 leaves on tree. Total mass=6.817906236519449. Fractional error=0.0031347577373897813.
# End of tree iteration 192: 8240 leaves on tree. Total mass=6.81662777165288. Fractional error=0.0031188425142447203.
# End of tree iteration 193: 8247 leaves on tree. Total mass=6.818556341227264. Fractional error=0.00310143977403976.
# End of tree iteration 194: 8254 leaves on tree. Total mass=6.8195778952098465. Fractional error=0.00308458294552691.
# End of tree iteration 195: 8261 leaves on tree. Total mass=6.820599290551791. Fractional error=0.003067643711312306.
# End of tree iteration 196: 8268 leaves on tree. Total mass=6.822221361067516. Fractional error=0.003050842023614937.
# End of tree iteration 197: 8275 leaves on tree. Total mass=6.819073951959442. Fractional error=0.0030362709308274158.
# End of tree iteration 198: 8282 leaves on tree. Total mass=6.821085161997506. Fractional error=0.003019679097589638.
# End of tree iteration 199: 8289 leaves on tree. Total mass=6.817791221324833. Fractional error=0.00300552022162846.
# End of tree iteration 200: 8296 leaves on tree. Total mass=6.809972160686073. Fractional error=0.002995853979598732.
# End of tree iteration 201: 8303 leaves on tree. Total mass=6.802153192626375. Fractional error=0.002986109108764033.
# End of tree iteration 202: 8310 leaves on tree. Total mass=6.8041297266115. Fractional error=0.002969796359386562.
# End of tree iteration 203: 8317 leaves on tree. Total mass=6.806106234930692. Fractional error=0.0029534127558988646.
# End of tree iteration 204: 8324 leaves on tree. Total mass=6.80774201398087. Fractional error=0.0029373142613888788.
# End of tree iteration 205: 8331 leaves on tree. Total mass=6.805122964958421. Fractional error=0.0029232705154074745.
# End of tree iteration 206: 8338 leaves on tree. Total mass=6.806060297617902. Fractional error=0.002907736511437929.
# End of tree iteration 207: 8345 leaves on tree. Total mass=6.80699706708856. Fractional error=0.002892128024786505.
# End of tree iteration 208: 8352 leaves on tree. Total mass=6.808935905088849. Fractional error=0.0028760805278504513.
# End of tree iteration 209: 8359 leaves on tree. Total mass=6.808002613923333. Fractional error=0.0028617895445383974.
# End of tree iteration 210: 8366 leaves on tree. Total mass=6.809152690171283. Fractional error=0.0028468803532650374.
# End of tree iteration 211: 8373 leaves on tree. Total mass=6.809032035830188. Fractional error=0.0028327233243616136.
# End of tree iteration 212: 8380 leaves on tree. Total mass=6.809181399356645. Fractional error=0.0028183075223683963.
# End of tree iteration 213: 8387 leaves on tree. Total mass=6.809330762859151. Fractional error=0.002803818876259426.
# End of tree iteration 214: 8394 leaves on tree. Total mass=6.810240715810256. Fractional error=0.0027896909524241383.
# End of tree iteration 215: 8401 leaves on tree. Total mass=6.811150343926999. Fractional error=0.0027754988645246805.
# End of tree iteration 216: 8408 leaves on tree. Total mass=6.807667167810896. Fractional error=0.002763564177054677.
# End of tree iteration 217: 8415 leaves on tree. Total mass=6.80377862573652. Fractional error=0.0027540197695797826.
# End of tree iteration 218: 8422 leaves on tree. Total mass=6.804293319766579. Fractional error=0.002740527868087613.
# End of tree iteration 219: 8429 leaves on tree. Total mass=6.804807843992655. Fractional error=0.0027269758487507042.
# End of tree iteration 220: 8436 leaves on tree. Total mass=6.802917955540091. Fractional error=0.002714270595373439.
# End of tree iteration 221: 8443 leaves on tree. Total mass=6.801028067087529. Fractional error=0.0027014911527130352.
# End of tree iteration 222: 8450 leaves on tree. Total mass=6.797854757885627. Fractional error=0.0026895769992490576.
# End of tree iteration 223: 8457 leaves on tree. Total mass=6.794681448710198. Fractional error=0.0026775868282868814.
# End of tree iteration 224: 8464 leaves on tree. Total mass=6.794625273401817. Fractional error=0.0026643184050173623.
# End of tree iteration 225: 8471 leaves on tree. Total mass=6.7962090809419555. Fractional error=0.0026504405629953092.
# End of tree iteration 226: 8478 leaves on tree. Total mass=6.796134637035893. Fractional error=0.002637546135159212.
# End of tree iteration 227: 8485 leaves on tree. Total mass=6.796578381743924. Fractional error=0.002624546541950302.
# End of tree iteration 228: 8492 leaves on tree. Total mass=6.797022126659938. Fractional error=0.0026114856478688156.
# End of tree iteration 229: 8499 leaves on tree. Total mass=6.7935995012257635. Fractional error=0.0026024536544106713.
# End of tree iteration 230: 8506 leaves on tree. Total mass=6.795138274259873. Fractional error=0.002590173451508524.
# End of tree iteration 231: 8513 leaves on tree. Total mass=6.796677047293985. Fractional error=0.0025778458139996516.
# End of tree iteration 232: 8520 leaves on tree. Total mass=6.796540916249396. Fractional error=0.0025655129189226457.
# End of tree iteration 233: 8527 leaves on tree. Total mass=6.798295246288946. Fractional error=0.0025528401251881964.
# End of tree iteration 234: 8534 leaves on tree. Total mass=6.800106485405714. Fractional error=0.0025401778396231863.
# End of tree iteration 235: 8541 leaves on tree. Total mass=6.801943168171379. Fractional error=0.0025276717783682444.
# End of tree iteration 236: 8548 leaves on tree. Total mass=6.800526490671885. Fractional error=0.002516852384520713.
# End of tree iteration 237: 8555 leaves on tree. Total mass=6.799770072680709. Fractional error=0.00250636831665885.
# End of tree iteration 238: 8562 leaves on tree. Total mass=6.799013608400004. Fractional error=0.002495836142653448.
# End of tree iteration 239: 8569 leaves on tree. Total mass=6.800913143563642. Fractional error=0.0024840727285053736.
# End of tree iteration 240: 8576 leaves on tree. Total mass=6.802812678700808. Fractional error=0.0024722663774196327.
# End of tree iteration 241: 8583 leaves on tree. Total mass=6.8028143735078554. Fractional error=0.0024614373062924553.
# End of tree iteration 242: 8590 leaves on tree. Total mass=6.803298074349768. Fractional error=0.0024501861666771764.
# End of tree iteration 243: 8597 leaves on tree. Total mass=6.8038032053085455. Fractional error=0.0024388758746026087.
# End of tree iteration 244: 8604 leaves on tree. Total mass=6.8042729020042465. Fractional error=0.00242753158585333.
# End of tree iteration 245: 8611 leaves on tree. Total mass=6.805887794858091. Fractional error=0.0024161219175449023.
# End of tree iteration 246: 8618 leaves on tree. Total mass=6.807851721012629. Fractional error=0.002404461452642308.
# End of tree iteration 247: 8625 leaves on tree. Total mass=6.807852254350527. Fractional error=0.0023935817754849203.
# End of tree iteration 248: 8632 leaves on tree. Total mass=6.810264458238246. Fractional error=0.0023819254202112144.
# End of tree iteration 249: 8639 leaves on tree. Total mass=6.812662757826312. Fractional error=0.002370484987243596.
# End of tree iteration 250: 8646 leaves on tree. Total mass=6.812576163612612. Fractional error=0.002360579226636215.
# End of tree iteration 251: 8653 leaves on tree. Total mass=6.810722490110878. Fractional error=0.0023508466013416125.
# End of tree iteration 252: 8660 leaves on tree. Total mass=6.808868816609147. Fractional error=0.0023410626718559408.
# End of tree iteration 253: 8667 leaves on tree. Total mass=6.80931757037498. Fractional error=0.0023306493162488636.
# End of tree iteration 254: 8674 leaves on tree. Total mass=6.809387047887079. Fractional error=0.002320244513479437.
# End of tree iteration 255: 8681 leaves on tree. Total mass=6.809020476136328. Fractional error=0.0023100966148930104.
# End of tree iteration 256: 8688 leaves on tree. Total mass=6.8049811196698515. Fractional error=0.0023019884672284873.
# End of tree iteration 257: 8695 leaves on tree. Total mass=6.804924059587938. Fractional error=0.0022921215759412706.
# End of tree iteration 258: 8702 leaves on tree. Total mass=6.804866999506024. Fractional error=0.002282211693379542.
# End of tree iteration 259: 8709 leaves on tree. Total mass=6.807709334887731. Fractional error=0.00227146420408156.
# End of tree iteration 260: 8716 leaves on tree. Total mass=6.8090054404217. Fractional error=0.00226114081542813.
# End of tree iteration 261: 8723 leaves on tree. Total mass=6.809790581910675. Fractional error=0.002251039756080491.
# End of tree iteration 262: 8730 leaves on tree. Total mass=6.808391039269822. Fractional error=0.002241990251438731.
# End of tree iteration 263: 8737 leaves on tree. Total mass=6.805957975507578. Fractional error=0.002233246119319459.
# End of tree iteration 264: 8744 leaves on tree. Total mass=6.803524911745336. Fractional error=0.00222445474180376.
# End of tree iteration 265: 8751 leaves on tree. Total mass=6.804750274533294. Fractional error=0.0022143143799533966.
# End of tree iteration 266: 8758 leaves on tree. Total mass=6.804283465038379. Fractional error=0.0022047459990867237.
# End of tree iteration 267: 8765 leaves on tree. Total mass=6.798201858186812. Fractional error=0.0021989361895205476.
# End of tree iteration 268: 8772 leaves on tree. Total mass=6.797742742945651. Fractional error=0.00218951755777424.
# End of tree iteration 269: 8779 leaves on tree. Total mass=6.796314771948272. Fractional error=0.0021805581330481827.
# End of tree iteration 270: 8786 leaves on tree. Total mass=6.795765636321563. Fractional error=0.0021715850281722655.
# End of tree iteration 271: 8793 leaves on tree. Total mass=6.795216249613307. Fractional error=0.002162575273101024.
# End of tree iteration 272: 8800 leaves on tree. Total mass=6.792499745000475. Fractional error=0.002154314621873531.
# End of tree iteration 273: 8807 leaves on tree. Total mass=6.794895993151799. Fractional error=0.0021444069942691017.
# End of tree iteration 274: 8814 leaves on tree. Total mass=6.797282231545246. Fractional error=0.002134605584876012.
# End of tree iteration 275: 8821 leaves on tree. Total mass=6.798185725452565. Fractional error=0.0021250745696090667.
# End of tree iteration 276: 8828 leaves on tree. Total mass=6.79901035144753. Fractional error=0.002115548951486069.
# End of tree iteration 277: 8835 leaves on tree. Total mass=6.800116663334254. Fractional error=0.002105883137631327.
# End of tree iteration 278: 8842 leaves on tree. Total mass=6.797539581519926. Fractional error=0.002097551260563249.
# End of tree iteration 279: 8849 leaves on tree. Total mass=6.798643869910331. Fractional error=0.002088049227323443.
# End of tree iteration 280: 8856 leaves on tree. Total mass=6.799231494879306. Fractional error=0.0020790138444182135.
# End of tree iteration 281: 8863 leaves on tree. Total mass=6.79981908387055. Fractional error=0.0020699426505939944.
# End of tree iteration 282: 8870 leaves on tree. Total mass=6.800979048228248. Fractional error=0.002060826868004045.
# End of tree iteration 283: 8877 leaves on tree. Total mass=6.802139012575232. Fractional error=0.002051676781931211.
# End of tree iteration 284: 8884 leaves on tree. Total mass=6.803269712293359. Fractional error=0.002042519841669002.
# End of tree iteration 285: 8891 leaves on tree. Total mass=6.803005977843389. Fractional error=0.0020341448647769574.
# End of tree iteration 286: 8898 leaves on tree. Total mass=6.803986369638063. Fractional error=0.0020252126844451453.
# End of tree iteration 287: 8905 leaves on tree. Total mass=6.804966529757973. Fractional error=0.0020162492905472346.
# End of tree iteration 288: 8912 leaves on tree. Total mass=6.80709566314906. Fractional error=0.00200744174686226.
# End of tree iteration 289: 8919 leaves on tree. Total mass=6.8083873815982905. Fractional error=0.001998591620548505.
# End of tree iteration 290: 8926 leaves on tree. Total mass=6.809399898358409. Fractional error=0.0019901135995510806.
# End of tree iteration 291: 8933 leaves on tree. Total mass=6.808891575097786. Fractional error=0.001982283468240175.
# End of tree iteration 292: 8940 leaves on tree. Total mass=6.809937345552354. Fractional error=0.0019739455835809483.
# End of tree iteration 293: 8947 leaves on tree. Total mass=6.808729458179742. Fractional error=0.0019662987918420325.
# End of tree iteration 294: 8954 leaves on tree. Total mass=6.80979262467282. Fractional error=0.0019579813951441185.
# End of tree iteration 295: 8961 leaves on tree. Total mass=6.810855791144469. Fractional error=0.0019496336937798449.
# End of tree iteration 296: 8968 leaves on tree. Total mass=6.812577104543541. Fractional error=0.0019415186755507945.
# End of tree iteration 297: 8975 leaves on tree. Total mass=6.813535983950677. Fractional error=0.0019333606869606568.
# End of tree iteration 298: 8982 leaves on tree. Total mass=6.814494863336383. Fractional error=0.001925172710988882.
# End of tree iteration 299: 8989 leaves on tree. Total mass=6.815003016401397. Fractional error=0.0019172728570345785.
# End of tree iteration 300: 8996 leaves on tree. Total mass=6.813636805932138. Fractional error=0.0019099164511134044.
# End of tree iteration 301: 9003 leaves on tree. Total mass=6.812270595462878. Fractional error=0.0019025255868443743.
# End of tree iteration 302: 9010 leaves on tree. Total mass=6.813059830967324. Fractional error=0.0018945088101242093.
# End of tree iteration 303: 9017 leaves on tree. Total mass=6.813983428051596. Fractional error=0.0018864408604491252.
# End of tree iteration 304: 9024 leaves on tree. Total mass=6.815673030169851. Fractional error=0.0018785262088268932.
# End of tree iteration 305: 9031 leaves on tree. Total mass=6.814037038200879. Fractional error=0.001871545751614042.
# End of tree iteration 306: 9038 leaves on tree. Total mass=6.814956574562608. Fractional error=0.0018635595781835918.
# End of tree iteration 307: 9045 leaves on tree. Total mass=6.813311305666996. Fractional error=0.00185664034983265.
# End of tree iteration 308: 9052 leaves on tree. Total mass=6.813746423754275. Fractional error=0.001848956838346246.
# End of tree iteration 309: 9059 leaves on tree. Total mass=6.812253969935689. Fractional error=0.0018417724170118187.
# End of tree iteration 310: 9066 leaves on tree. Total mass=6.8126634150649625. Fractional error=0.0018340436637690083.
# End of tree iteration 311: 9073 leaves on tree. Total mass=6.8130727882387685. Fractional error=0.001826285050959533.
# End of tree iteration 312: 9080 leaves on tree. Total mass=6.813135270831953. Fractional error=0.001818825923662425.
# End of tree iteration 313: 9087 leaves on tree. Total mass=6.813286625564865. Fractional error=0.0018117179741944608.
# End of tree iteration 314: 9094 leaves on tree. Total mass=6.813849830744094. Fractional error=0.0018043772639772658.
# End of tree iteration 315: 9101 leaves on tree. Total mass=6.8132050010265415. Fractional error=0.0017975079803927128.
# End of tree iteration 316: 9108 leaves on tree. Total mass=6.815267812605551. Fractional error=0.001790014121493071.
# End of tree iteration 317: 9115 leaves on tree. Total mass=6.814411004936147. Fractional error=0.001783498469659067.
# End of tree iteration 318: 9122 leaves on tree. Total mass=6.8164537969994035. Fractional error=0.0017762194802300741.
# End of tree iteration 319: 9129 leaves on tree. Total mass=6.811442595610267. Fractional error=0.0017726173556465586.
# End of tree iteration 320: 9136 leaves on tree. Total mass=6.811297890721519. Fractional error=0.0017658502969221837.
# End of tree iteration 321: 9143 leaves on tree. Total mass=6.809463094432145. Fractional error=0.001759580813637162.
# End of tree iteration 322: 9150 leaves on tree. Total mass=6.810109785202854. Fractional error=0.00175266268283507.
# End of tree iteration 323: 9157 leaves on tree. Total mass=6.809943054458001. Fractional error=0.0017461057936444147.
# End of tree iteration 324: 9164 leaves on tree. Total mass=6.805039139532524. Fractional error=0.0017437715367855202.
# End of tree iteration 325: 9171 leaves on tree. Total mass=6.807262162804351. Fractional error=0.0017396378292907032.
# End of tree iteration 326: 9178 leaves on tree. Total mass=6.809485129474851. Fractional error=0.0017355002438637606.
# End of tree iteration 327: 9185 leaves on tree. Total mass=6.81017906280897. Fractional error=0.001728706050255847.
# End of tree iteration 328: 9192 leaves on tree. Total mass=6.8109715168642575. Fractional error=0.0017220076459743155.
# End of tree iteration 329: 9199 leaves on tree. Total mass=6.81176397090883. Fractional error=0.0017152861954958087.
# End of tree iteration 330: 9206 leaves on tree. Total mass=6.812475161652863. Fractional error=0.0017085871680008705.
# End of tree iteration 331: 9213 leaves on tree. Total mass=6.81123576686489. Fractional error=0.0017024490915925929.
# End of tree iteration 332: 9220 leaves on tree. Total mass=6.809996372076917. Fractional error=0.0016962842543382943.
# End of tree iteration 333: 9227 leaves on tree. Total mass=6.809613283220233. Fractional error=0.001690353322352945.
# End of tree iteration 334: 9234 leaves on tree. Total mass=6.809230194351572. Fractional error=0.0016844001600826001.
# End of tree iteration 335: 9241 leaves on tree. Total mass=6.810336538441529. Fractional error=0.001678038333981079.
# End of tree iteration 336: 9248 leaves on tree. Total mass=6.805494540741757. Fractional error=0.0016762799550663963.
# End of tree iteration 337: 9255 leaves on tree. Total mass=6.804405957745249. Fractional error=0.0016708141946579758.
# End of tree iteration 338: 9262 leaves on tree. Total mass=6.805474468178652. Fractional error=0.0016645471976426448.
# End of tree iteration 339: 9269 leaves on tree. Total mass=6.804372891490506. Fractional error=0.001659203152355155.
# End of tree iteration 340: 9276 leaves on tree. Total mass=6.803295633625938. Fractional error=0.0016535785790532007.
# End of tree iteration 341: 9283 leaves on tree. Total mass=6.801823025487425. Fractional error=0.0016480664583917366.
# End of tree iteration 342: 9290 leaves on tree. Total mass=6.803101749831799. Fractional error=0.0016425931491395745.
# End of tree iteration 343: 9297 leaves on tree. Total mass=6.804145322211033. Fractional error=0.0016367622430337918.
# End of tree iteration 344: 9304 leaves on tree. Total mass=6.806420934482601. Fractional error=0.001630835238145564.
# End of tree iteration 345: 9311 leaves on tree. Total mass=6.805303072687171. Fractional error=0.0016259576151039.
# End of tree iteration 346: 9318 leaves on tree. Total mass=6.804185118312681. Fractional error=0.0016210632031991238.
# End of tree iteration 347: 9325 leaves on tree. Total mass=6.804078363767247. Fractional error=0.0016155973724697906.
# End of tree iteration 348: 9332 leaves on tree. Total mass=6.803971537266347. Fractional error=0.0016101135381686607.
# End of tree iteration 349: 9339 leaves on tree. Total mass=6.804427550532479. Fractional error=0.0016044550339033156.
# End of tree iteration 350: 9346 leaves on tree. Total mass=6.804921134922839. Fractional error=0.0015988722450583622.
# End of tree iteration 351: 9353 leaves on tree. Total mass=6.806964699508507. Fractional error=0.0015930827515828478.
# End of tree iteration 352: 9360 leaves on tree. Total mass=6.805039108445145. Fractional error=0.0015881993081720805.
# End of tree iteration 353: 9367 leaves on tree. Total mass=6.804927324227011. Fractional error=0.0015829965800758946.
# End of tree iteration 354: 9374 leaves on tree. Total mass=6.8046583038959545. Fractional error=0.0015779603947998256.
# End of tree iteration 355: 9381 leaves on tree. Total mass=6.805476505353238. Fractional error=0.0015723213313709758.
# End of tree iteration 356: 9388 leaves on tree. Total mass=6.803731988204638. Fractional error=0.0015673587193228192.
# End of tree iteration 357: 9395 leaves on tree. Total mass=6.804212657714242. Fractional error=0.0015617983732391031.
# End of tree iteration 358: 9402 leaves on tree. Total mass=6.802384826778614. Fractional error=0.0015573355715606694.
# End of tree iteration 359: 9409 leaves on tree. Total mass=6.802849825907797. Fractional error=0.0015517759292587756.
# End of tree iteration 360: 9416 leaves on tree. Total mass=6.802672436529569. Fractional error=0.0015467682727442038.
# End of tree iteration 361: 9423 leaves on tree. Total mass=6.80307844114512. Fractional error=0.0015412537679925075.
# End of tree iteration 362: 9430 leaves on tree. Total mass=6.803484445724743. Fractional error=0.0015357207800354294.
# End of tree iteration 363: 9437 leaves on tree. Total mass=6.803952066841215. Fractional error=0.001530152999037288.
# End of tree iteration 364: 9444 leaves on tree. Total mass=6.802401567633956. Fractional error=0.0015252629464356452.
# End of tree iteration 365: 9451 leaves on tree. Total mass=6.800853619201611. Fractional error=0.0015203766527379504.
# End of tree iteration 366: 9458 leaves on tree. Total mass=6.800198967295534. Fractional error=0.0015153449054109505.
# End of tree iteration 367: 9465 leaves on tree. Total mass=6.799148935217126. Fractional error=0.0015105264643478675.
# End of tree iteration 368: 9472 leaves on tree. Total mass=6.7993570915981785. Fractional error=0.0015052881479948577.
# End of tree iteration 369: 9479 leaves on tree. Total mass=6.798030560230597. Fractional error=0.0015004699363674791.
# End of tree iteration 370: 9486 leaves on tree. Total mass=6.798254917755335. Fractional error=0.0014954967367906116.
# End of tree iteration 371: 9493 leaves on tree. Total mass=6.797724141075116. Fractional error=0.0014907757781717392.
# End of tree iteration 372: 9500 leaves on tree. Total mass=6.797904704667442. Fractional error=0.0014860664821001919.
# End of tree iteration 373: 9507 leaves on tree. Total mass=6.796334881036388. Fractional error=0.0014817839629294243.
# End of tree iteration 374: 9514 leaves on tree. Total mass=6.7965530482056735. Fractional error=0.0014770418747922182.
# End of tree iteration 375: 9521 leaves on tree. Total mass=6.796188603613659. Fractional error=0.0014728159692579542.
# End of tree iteration 376: 9528 leaves on tree. Total mass=6.796581379377868. Fractional error=0.0014680132380252395.
# End of tree iteration 377: 9535 leaves on tree. Total mass=6.799027087571639. Fractional error=0.0014631655215380068.
# End of tree iteration 378: 9542 leaves on tree. Total mass=6.799136632522891. Fractional error=0.001458525496323855.
# End of tree iteration 379: 9549 leaves on tree. Total mass=6.797285130236641. Fractional error=0.0014548499039472268.
# End of tree iteration 380: 9556 leaves on tree. Total mass=6.7972984574761295. Fractional error=0.0014502340894993965.
# End of tree iteration 381: 9563 leaves on tree. Total mass=6.7976789189673825. Fractional error=0.0014454983311790563.
# End of tree iteration 382: 9570 leaves on tree. Total mass=6.799281273416726. Fractional error=0.0014405682713174344.
# End of tree iteration 383: 9577 leaves on tree. Total mass=6.799905887743873. Fractional error=0.0014357778779078324.
# End of tree iteration 384: 9584 leaves on tree. Total mass=6.8005304507391475. Fractional error=0.001430973823509619.
# End of tree iteration 385: 9591 leaves on tree. Total mass=6.8012382786098975. Fractional error=0.001426151154386636.
# End of tree iteration 386: 9598 leaves on tree. Total mass=6.802515267447534. Fractional error=0.0014216830607672792.
# End of tree iteration 387: 9605 leaves on tree. Total mass=6.801694701372158. Fractional error=0.0014173062800221451.
# End of tree iteration 388: 9612 leaves on tree. Total mass=6.802107301429963. Fractional error=0.0014126763761637012.
# End of tree iteration 389: 9619 leaves on tree. Total mass=6.802734041511671. Fractional error=0.0014080198580922916.
# End of tree iteration 390: 9626 leaves on tree. Total mass=6.803360755927442. Fractional error=0.0014033499092206696.
# End of tree iteration 391: 9633 leaves on tree. Total mass=6.8036689740903675. Fractional error=0.0013988692463509996.
# End of tree iteration 392: 9640 leaves on tree. Total mass=6.802602344444056. Fractional error=0.0013950556036832022.
# End of tree iteration 393: 9647 leaves on tree. Total mass=6.801301193309341. Fractional error=0.0013913520933415194.
# End of tree iteration 394: 9654 leaves on tree. Total mass=6.801886861855703. Fractional error=0.0013868244684933106.
# End of tree iteration 395: 9661 leaves on tree. Total mass=6.802472504736128. Fractional error=0.00138228387621574.
# End of tree iteration 396: 9668 leaves on tree. Total mass=6.802919172007654. Fractional error=0.0013777986685745635.
# End of tree iteration 397: 9675 leaves on tree. Total mass=6.801613747645735. Fractional error=0.0013740930691240895.
# End of tree iteration 398: 9682 leaves on tree. Total mass=6.801740213111699. Fractional error=0.0013697952223056123.
# End of tree iteration 399: 9689 leaves on tree. Total mass=6.802336205768791. Fractional error=0.0013653115096807856.
# End of tree iteration 400: 9696 leaves on tree. Total mass=6.802932147094008. Fractional error=0.0013608152058897933.
# End of tree iteration 401: 9703 leaves on tree. Total mass=6.801530424130988. Fractional error=0.0013570045818944217.
# End of tree iteration 402: 9710 leaves on tree. Total mass=6.802178671839256. Fractional error=0.001352560079464306.
# End of tree iteration 403: 9717 leaves on tree. Total mass=6.8012908761693645. Fractional error=0.0013484613311640881.
# End of tree iteration 404: 9724 leaves on tree. Total mass=6.798755147824251. Fractional error=0.0013453454375177093.
# End of tree iteration 405: 9731 leaves on tree. Total mass=6.799365722279443. Fractional error=0.0013410496959690643.
# End of tree iteration 406: 9738 leaves on tree. Total mass=6.799993321009688. Fractional error=0.0013367749133471841.
# ...
# End of tree iteration 2128: 21792 leaves on tree. Total mass=6.733218843748073. Fractional error=0.0002143325701010251.
# End of tree iteration 2129: 21799 leaves on tree. Total mass=6.7332407699644. Fractional error=0.0002141919943550067.
# End of tree iteration 2130: 21806 leaves on tree. Total mass=6.733422761053381. Fractional error=0.00021406277057914267.
# End of tree iteration 2131: 21813 leaves on tree. Total mass=6.733732107564996. Fractional error=0.00021397500683586053.
# End of tree iteration 2132: 21820 leaves on tree. Total mass=6.734041385276127. Fractional error=0.00021388759257746014.
# End of tree iteration 2133: 21827 leaves on tree. Total mass=6.734074449783268. Fractional error=0.00021374703198015618.
# End of tree iteration 2134: 21834 leaves on tree. Total mass=6.7339980773036805. Fractional error=0.00021361075501669146.
# End of tree iteration 2135: 21841 leaves on tree. Total mass=6.734092728854551. Fractional error=0.00021348466099804957.
# End of tree iteration 2136: 21848 leaves on tree. Total mass=6.733989130934418. Fractional error=0.00021335030551723964.
# End of tree iteration 2137: 21855 leaves on tree. Total mass=6.7338855330653455. Fractional error=0.0002132158573194478.
# End of tree iteration 2138: 21862 leaves on tree. Total mass=6.733915403478021. Fractional error=0.00021307630311255543.
# End of tree iteration 2139: 21869 leaves on tree. Total mass=6.73350717677887. Fractional error=0.00021305778984054852.
# End of tree iteration 2140: 21876 leaves on tree. Total mass=6.733522997915587. Fractional error=0.00021291966224401703.
# End of tree iteration 2141: 21883 leaves on tree. Total mass=6.733538819052303. Fractional error=0.0002127814462799092.
# End of tree iteration 2142: 21890 leaves on tree. Total mass=6.733515930818136. Fractional error=0.0002126481366072841.
# End of tree iteration 2143: 21897 leaves on tree. Total mass=6.73341708451577. Fractional error=0.00021251438208947396.
# End of tree iteration 2144: 21904 leaves on tree. Total mass=6.733318238281485. Fractional error=0.00021238053578987687.
# End of tree iteration 2145: 21911 leaves on tree. Total mass=6.733298641652422. Fractional error=0.00021224567252156742.
# End of tree iteration 2146: 21918 leaves on tree. Total mass=6.733337739365056. Fractional error=0.0002121065421003319.
# End of tree iteration 2147: 21925 leaves on tree. Total mass=6.733317961788213. Fractional error=0.00021197247581114582.
# End of tree iteration 2148: 21932 leaves on tree. Total mass=6.733437767139854. Fractional error=0.00021184036612491037.
# End of tree iteration 2149: 21939 leaves on tree. Total mass=6.73335528088441. Fractional error=0.00021170690786009218.
# End of tree iteration 2150: 21946 leaves on tree. Total mass=6.733378979281758. Fractional error=0.00021156949263728382.
# End of tree iteration 2151: 21953 leaves on tree. Total mass=6.733362077107385. Fractional error=0.00021143504820540196.
# End of tree iteration 2152: 21960 leaves on tree. Total mass=6.73295438735045. Fractional error=0.00021141898244092812.
# End of tree iteration 2153: 21967 leaves on tree. Total mass=6.732811946872813. Fractional error=0.0002112923847140982.
# End of tree iteration 2154: 21974 leaves on tree. Total mass=6.7323203195509045. Fractional error=0.00021126007444961155.
# End of tree iteration 2155: 21981 leaves on tree. Total mass=6.73248393739988. Fractional error=0.00021114606405137488.
# End of tree iteration 2156: 21988 leaves on tree. Total mass=6.731924643070626. Fractional error=0.0002111446713706966.
# End of tree iteration 2157: 21995 leaves on tree. Total mass=6.731433094903867. Fractional error=0.00021111272583178403.
# End of tree iteration 2158: 22002 leaves on tree. Total mass=6.731454996886374. Fractional error=0.00021097607487665745.
# End of tree iteration 2159: 22009 leaves on tree. Total mass=6.731486627576699. Fractional error=0.00021083928226540706.
# End of tree iteration 2160: 22016 leaves on tree. Total mass=6.731504222997907. Fractional error=0.00021070348029460844.
# End of tree iteration 2161: 22023 leaves on tree. Total mass=6.731487006603436. Fractional error=0.00021057116754401227.
# End of tree iteration 2162: 22030 leaves on tree. Total mass=6.731656708869157. Fractional error=0.00021047262566392788.
# End of tree iteration 2163: 22037 leaves on tree. Total mass=6.731773114142286. Fractional error=0.00021035273093835357.
# End of tree iteration 2164: 22044 leaves on tree. Total mass=6.7317753868602415. Fractional error=0.0002102193980999357.
# End of tree iteration 2165: 22051 leaves on tree. Total mass=6.731665763747667. Fractional error=0.00021009161653245812.
# End of tree iteration 2166: 22058 leaves on tree. Total mass=6.7318355983114575. Fractional error=0.00020999357785377365.
# End of tree iteration 2167: 22065 leaves on tree. Total mass=6.7320557798077285. Fractional error=0.00020989310733373397.
# End of tree iteration 2168: 22072 leaves on tree. Total mass=6.732275961244859. Fractional error=0.0002097926019427135.
# End of tree iteration 2169: 22079 leaves on tree. Total mass=6.732300024889287. Fractional error=0.00020965760759646842.
# End of tree iteration 2170: 22086 leaves on tree. Total mass=6.732308880066305. Fractional error=0.00020952896885495222.
# End of tree iteration 2171: 22093 leaves on tree. Total mass=6.7323110179339904. Fractional error=0.0002093957804683459.
# End of tree iteration 2172: 22100 leaves on tree. Total mass=6.7318258794562364. Fractional error=0.00020936556078326006.
# End of tree iteration 2173: 22107 leaves on tree. Total mass=6.731340788382193. Fractional error=0.0002093355756877714.
# End of tree iteration 2174: 22114 leaves on tree. Total mass=6.731330808878273. Fractional error=0.00020920535317497832.
# End of tree iteration 2175: 22121 leaves on tree. Total mass=6.731193621662309. Fractional error=0.00020908145378837806.
# End of tree iteration 2176: 22128 leaves on tree. Total mass=6.73105643449741. Fractional error=0.00020895747100839276.
# End of tree iteration 2177: 22135 leaves on tree. Total mass=6.731090272847756. Fractional error=0.00020882389702498054.
# End of tree iteration 2178: 22142 leaves on tree. Total mass=6.731209621426013. Fractional error=0.00020872663989470925.
# End of tree iteration 2179: 22149 leaves on tree. Total mass=6.7312414149526. Fractional error=0.00020859363220472518.
# End of tree iteration 2180: 22156 leaves on tree. Total mass=6.730690227989906. Fractional error=0.00020859427619593482.
# End of tree iteration 2181: 22163 leaves on tree. Total mass=6.730651184172919. Fractional error=0.00020847530238840645.
# End of tree iteration 2182: 22170 leaves on tree. Total mass=6.730682185511806. Fractional error=0.00020834209569504586.
# End of tree iteration 2183: 22177 leaves on tree. Total mass=6.730713186826119. Fractional error=0.00020820880636243641.
# End of tree iteration 2184: 22184 leaves on tree. Total mass=6.730752139894736. Fractional error=0.00020807536526816064.
# End of tree iteration 2185: 22191 leaves on tree. Total mass=6.730791092963349. Fractional error=0.00020794184162670955.
# End of tree iteration 2186: 22198 leaves on tree. Total mass=6.730834686069281. Fractional error=0.00020780826075236108.
# End of tree iteration 2187: 22205 leaves on tree. Total mass=6.7308782791752115. Fractional error=0.00020767459741105615.
# End of tree iteration 2188: 22212 leaves on tree. Total mass=6.730780985315981. Fractional error=0.00020754686528432986.
# End of tree iteration 2189: 22219 leaves on tree. Total mass=6.730816182429789. Fractional error=0.00020741356752763745.
# End of tree iteration 2190: 22226 leaves on tree. Total mass=6.730806236290287. Fractional error=0.00020728475748437973.
# End of tree iteration 2191: 22233 leaves on tree. Total mass=6.730796290078297. Fractional error=0.00020715586696947754.
# End of tree iteration 2192: 22240 leaves on tree. Total mass=6.730535494654828. Fractional error=0.0002071121514734508.
# End of tree iteration 2193: 22247 leaves on tree. Total mass=6.730581018140419. Fractional error=0.00020697982020414257.
# End of tree iteration 2194: 22254 leaves on tree. Total mass=6.730626541626009. Fractional error=0.00020684740784960957.
# End of tree iteration 2195: 22261 leaves on tree. Total mass=6.730746495359988. Fractional error=0.0002067510371163317.
# End of tree iteration 2196: 22268 leaves on tree. Total mass=6.730866459441575. Fractional error=0.00020665468252052286.
# End of tree iteration 2197: 22275 leaves on tree. Total mass=6.7306055989585705. Fractional error=0.00020661116869235044.
# End of tree iteration 2198: 22282 leaves on tree. Total mass=6.730646076656797. Fractional error=0.0002064789812742421.
# End of tree iteration 2199: 22289 leaves on tree. Total mass=6.730675699902596. Fractional error=0.00020634734926534842.
# End of tree iteration 2200: 22296 leaves on tree. Total mass=6.7307053231320095. Fractional error=0.00020621563563559347.
# End of tree iteration 2201: 22303 leaves on tree. Total mass=6.730067025998855. Fractional error=0.00020648634975786888.
# End of tree iteration 2202: 22310 leaves on tree. Total mass=6.730106697535846. Fractional error=0.00020628342943890797.
# End of tree iteration 2203: 22317 leaves on tree. Total mass=6.7299579714348745. Fractional error=0.00020617288111248779.
# End of tree iteration 2204: 22324 leaves on tree. Total mass=6.7298374727328. Fractional error=0.0002060500824883487.
# End of tree iteration 2205: 22331 leaves on tree. Total mass=6.7299932074785325. Fractional error=0.00020594087606895316.
# End of tree iteration 2206: 22338 leaves on tree. Total mass=6.730165318075536. Fractional error=0.00020582030335857102.
# End of tree iteration 2207: 22345 leaves on tree. Total mass=6.730068702680975. Fractional error=0.00020571431250683352.
# End of tree iteration 2208: 22352 leaves on tree. Total mass=6.729988512512684. Fractional error=0.00020558673277047018.
# End of tree iteration 2209: 22359 leaves on tree. Total mass=6.729908322380959. Fractional error=0.00020545906789039612.
# End of tree iteration 2210: 22366 leaves on tree. Total mass=6.7298116983053475. Fractional error=0.00020535291816456858.
# End of tree iteration 2211: 22373 leaves on tree. Total mass=6.729825104618545. Fractional error=0.00020522233494582807.
# End of tree iteration 2212: 22380 leaves on tree. Total mass=6.729820728127497. Fractional error=0.00020509511413243034.
# End of tree iteration 2213: 22387 leaves on tree. Total mass=6.7297604711115495. Fractional error=0.00020497675318933737.
# End of tree iteration 2214: 22394 leaves on tree. Total mass=6.729917686239398. Fractional error=0.00020487063076659164.
# End of tree iteration 2215: 22401 leaves on tree. Total mass=6.730044313536855. Fractional error=0.00020479426963659615.
# End of tree iteration 2216: 22408 leaves on tree. Total mass=6.73008076079792. Fractional error=0.00020466624735098195.
# End of tree iteration 2217: 22415 leaves on tree. Total mass=6.729740879375658. Fractional error=0.00020462071119229123.
# End of tree iteration 2218: 22422 leaves on tree. Total mass=6.7297044149066565. Fractional error=0.00020449511735348092.
# End of tree iteration 2219: 22429 leaves on tree. Total mass=6.729629942530959. Fractional error=0.0002043713492749097.
# End of tree iteration 2220: 22436 leaves on tree. Total mass=6.729650124875651. Fractional error=0.0002042444549500955.
# End of tree iteration 2221: 22443 leaves on tree. Total mass=6.729670307133356. Fractional error=0.00020411748371804912.
# End of tree iteration 2222: 22450 leaves on tree. Total mass=6.729820760344166. Fractional error=0.00020401114283952307.
# End of tree iteration 2223: 22457 leaves on tree. Total mass=6.729728188324421. Fractional error=0.00020390532693450304.
# End of tree iteration 2224: 22464 leaves on tree. Total mass=6.729388492579355. Fractional error=0.00020386050144404386.
# End of tree iteration 2225: 22471 leaves on tree. Total mass=6.729390553911831. Fractional error=0.00020373469029764992.
# End of tree iteration 2226: 22478 leaves on tree. Total mass=6.729407135621679. Fractional error=0.0002036084227665052.
# End of tree iteration 2227: 22485 leaves on tree. Total mass=6.729423717263448. Fractional error=0.0002034820784845368.
# End of tree iteration 2228: 22492 leaves on tree. Total mass=6.729398530163597. Fractional error=0.00020335702207256688.
# End of tree iteration 2229: 22499 leaves on tree. Total mass=6.729356497855882. Fractional error=0.00020323269648905127.
# End of tree iteration 2230: 22506 leaves on tree. Total mass=6.729314465548168. Fractional error=0.00020310829168699465.
# End of tree iteration 2231: 22513 leaves on tree. Total mass=6.729333056953614. Fractional error=0.00020298234344530308.
# End of tree iteration 2232: 22520 leaves on tree. Total mass=6.729356254057379. Fractional error=0.00020285689248704118.
# End of tree iteration 2233: 22527 leaves on tree. Total mass=6.729379451144761. Fractional error=0.0002027313657142186.
# End of tree iteration 2234: 22534 leaves on tree. Total mass=6.729240384291397. Fractional error=0.00020261692213067545.
# End of tree iteration 2235: 22541 leaves on tree. Total mass=6.7292734059797255. Fractional error=0.00020249129453448907.
# End of tree iteration 2236: 22548 leaves on tree. Total mass=6.729148748330108. Fractional error=0.0002023752242993064.
# End of tree iteration 2237: 22555 leaves on tree. Total mass=6.729235814518882. Fractional error=0.0002022601026367253.
# End of tree iteration 2238: 22562 leaves on tree. Total mass=6.729319221709093. Fractional error=0.00020214853142595994.
# End of tree iteration 2239: 22569 leaves on tree. Total mass=6.7292437515785455. Fractional error=0.00020202751461833882.
# End of tree iteration 2240: 22576 leaves on tree. Total mass=6.729036299236216. Fractional error=0.00020195682155340757.
# End of tree iteration 2241: 22583 leaves on tree. Total mass=6.728804871040925. Fractional error=0.0002018683252126692.
# End of tree iteration 2242: 22590 leaves on tree. Total mass=6.7288325543300385. Fractional error=0.0002017436504532153.
# End of tree iteration 2243: 22597 leaves on tree. Total mass=6.729054733628994. Fractional error=0.00020163657307981705.
# End of tree iteration 2244: 22604 leaves on tree. Total mass=6.729017707902628. Fractional error=0.00020151439698435513.
# End of tree iteration 2245: 22611 leaves on tree. Total mass=6.728904210307741. Fractional error=0.000201403305731379.
# End of tree iteration 2246: 22618 leaves on tree. Total mass=6.728749822583109. Fractional error=0.00020129897400197587.
# End of tree iteration 2247: 22625 leaves on tree. Total mass=6.728788778443519. Fractional error=0.0002011747570742371.
# End of tree iteration 2248: 22632 leaves on tree. Total mass=6.728758398133799. Fractional error=0.00020105763959333913.
# End of tree iteration 2249: 22639 leaves on tree. Total mass=6.728796314973772. Fractional error=0.00020093417036050394.
# End of tree iteration 2250: 22646 leaves on tree. Total mass=6.728834231813744. Fractional error=0.00020081062799127527.
# End of tree iteration 2251: 22653 leaves on tree. Total mass=6.728515871777785. Fractional error=0.0002007351991340506.
# End of tree iteration 2252: 22660 leaves on tree. Total mass=6.7279096798053795. Fractional error=0.0002008473821397713.
# End of tree iteration 2253: 22667 leaves on tree. Total mass=6.727827249279927. Fractional error=0.00020074076934218241.
# End of tree iteration 2254: 22674 leaves on tree. Total mass=6.727696401467883. Fractional error=0.0002006448337967185.
# End of tree iteration 2255: 22681 leaves on tree. Total mass=6.727732972095284. Fractional error=0.00020052210583031423.
# End of tree iteration 2256: 22688 leaves on tree. Total mass=6.727414781545936. Fractional error=0.00020044738682374448.
# End of tree iteration 2257: 22695 leaves on tree. Total mass=6.727417532937213. Fractional error=0.00020032689113772936.
# End of tree iteration 2258: 22702 leaves on tree. Total mass=6.727474138775916. Fractional error=0.00020021691146143475.
# End of tree iteration 2259: 22709 leaves on tree. Total mass=6.727516476602002. Fractional error=0.0002000946449375468.

# %% [markdown]
# We can visualise the refinement of the tree:

# %%
from matplotlib.patches import Rectangle
fig = plt.figure()
ax = fig.add_subplot(111)

for leaf in tree.leaves:
    rect = Rectangle((leaf.x[0], leaf.x[2]), leaf.dx[0], leaf.dx[2], lw=1, facecolor='none', ec='k', alpha=0.6)
    ax.add_patch(rect)
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %% [markdown]
# And then sample from the tree:

# %%
sampler = LintSampler(domain=tree,seed=rng)
X = sampler.sample(N=1000000)

# %% [markdown]
# Lastly, visualise to compare with our results before:

# %%
plt.hist2d(X[:, 0], X[:, 2], bins=np.linspace(-10, 10, 1000), density=True, norm=LogNorm())
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar();

# %% [markdown]
# While we do see some tree artefacts, notice that with `DensityTree` we are more accurately representing the very low-density outskirts of the NFW profile. We could remove the artefacts by decreasing the tolerance -- at the expense of more computational time. Choose tolerances that are appropriate for your problem!
